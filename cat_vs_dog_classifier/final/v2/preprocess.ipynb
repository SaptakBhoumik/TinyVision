# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import local_binary_pattern
from PIL import Image
import math
from concurrent.futures import ProcessPoolExecutor
import os

# %%
def contrast_stretch(img):
    # Stretching pixel intensities to [0, 255] range
    min_val = np.min(img)
    max_val = np.max(img)
    
    if max_val == min_val:
        return img.copy()  # avoid division by zero if image is flat

    stretched = (img - min_val) * (255.0 / (max_val - min_val))
    return stretched.astype(np.uint8)

# %%
def multi_pass_enhance_gray(img, output_shape = (512,512)):
    # 1. Initial upscale
    result = cv2.resize(img, output_shape, interpolation=cv2.INTER_LANCZOS4)

    # 2. Denoising
    result = cv2.fastNlMeansDenoising(result, None, h=10, templateWindowSize=7, searchWindowSize=21)

    # 3. Contrast enhancement
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
    result = clahe.apply(result)
    result = contrast_stretch(result)

    # 4. Sharpening
    kernel = np.array([[0,-1,0], [-1,5,-1], [0,-1,0]], dtype=np.float32)
    result = cv2.filter2D(result, -1, kernel)

    return np.clip(result, 0, 255).astype(np.uint8)

# %%
def otsu_threshold(img):
    value, thresh = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    return value,thresh

# %%
def canny(img, t1, t2):
    edges = cv2.Canny(img, t1, t2)
    return edges

# %%
def scharr(img, scale, delta):
    scharr_x = cv2.Scharr(img, cv2.CV_64F, 1, 0, scale=scale, delta=delta)
    scharr_y = cv2.Scharr(img, cv2.CV_64F, 0, 1, scale=scale, delta=delta)
    scharr_edges = np.sqrt(scharr_x**2 + scharr_y**2)
    return np.clip(scharr_edges, 0, 255).astype(np.uint8)

# %%
def lbp(img, P, R):
    # Local Binary Pattern
    lbp = local_binary_pattern(img, P, R, method='uniform')
    # Normalize LBP to [0, 255]
    lbp_normalized = (lbp / np.max(lbp) * 255).astype(np.uint8)
    return lbp_normalized

# %%
def gabor(img, theta, ksize, sigma, lambd, gamma, phi):
    # Gabor filter
    kernel = cv2.getGaborKernel((ksize, ksize), sigma, theta, lambd, gamma, phi, ktype=cv2.CV_32F)
    gabor_filtered = cv2.filter2D(img, cv2.CV_8UC1, kernel)
    return gabor_filtered

# %%
def pipeline(path, output_shape, canny_ratios, scharr_combos, lbp_configs, gabor_configs):
    img = np.array(Image.open(path).convert("L"))
    if img is None:
        raise ValueError("Image not found or unable to read.")
    res = []
    # Multi-pass enhancement
    enhanced_img = multi_pass_enhance_gray(img, output_shape = (512,512))
    res.append(enhanced_img)
    # Otsu's thresholding
    otsu_value, otsu_thresh = otsu_threshold(enhanced_img)
    res.append(otsu_thresh)
    # Canny edge detection
    for t1_ratio, t2_ratio in canny_ratios:
        t1 = int(otsu_value * t1_ratio)
        t2 = int(otsu_value * t2_ratio)
        canny_edges = canny(enhanced_img, t1, t2)
        res.append(canny_edges)
    # Scharr gradient
    for scale, delta in scharr_combos:
        scharr_edges = scharr(enhanced_img, scale, delta)
        res.append(scharr_edges)

    # Local Binary Pattern
    for P, R in lbp_configs:
        lbp_img = lbp(enhanced_img, P, R)
        res.append(lbp_img)

    # Gabor filter
    for theta in gabor_configs:
        gabor_img = gabor(enhanced_img, theta, 21, 8, 10, 0.5, 0)
        res.append(gabor_img)

    res = [cv2.resize(r, output_shape, interpolation=cv2.INTER_LANCZOS4) for r in res]
    
    return res, np.flip(res, axis=2)
    
def preprocess(config, path, every_file, output_path,id):
    output_shape = config['output_shape']
    canny_ratios = config['canny_ratios']
    scharr_combos = config['scharr_combos']
    lbp_configs = config['lbp_configs']
    gabor_configs = config['gabor_configs']

    original_path = os.path.join(output_path, "original")
    lr_path = os.path.join(output_path, "lr")

    os.makedirs(original_path, exist_ok=True)
    os.makedirs(lr_path, exist_ok=True)

    chunked = [every_file[i:i + 100] for i in range(0, len(every_file), 100)]

    for idx, files in enumerate(chunked):
        res1, res2 = [], []
        for file in files:
            file_path = os.path.join(path, file)
            a,b = pipeline(file_path,output_shape = output_shape,
                           canny_ratios = canny_ratios, 
                           scharr_combos = scharr_combos, 
                           lbp_configs = lbp_configs, 
                           gabor_configs = gabor_configs)
            res1.append(a)
            res2.append(b)

        res1 = np.stack(res1, axis=0)
        res2 = np.stack(res2, axis=0)

        path1 = os.path.join(original_path, f"{id}_{idx}.npy")
        path2 = os.path.join(lr_path, f"{id}_{idx}.npy")
        np.save(path1, res1)
        np.save(path2, res2)

        print(f"✅ Wrote {res1.shape} to {path1} and {res2.shape} to {path2}")

        
def preprocess_wrapper(args):
    return preprocess(*args)

def is_image_file(path: str,skip) -> bool:
    valid_extensions = ['.jpg', '.jpeg', '.png', '.bmp', '.tiff']
    return os.path.splitext(path)[1].lower() in valid_extensions and path not in skip

# %%
cat_files = sorted(os.listdir("../../../dataset/DogVsCatDataset/PetImages/Cat"))
dog_files = sorted(os.listdir("../../../dataset/DogVsCatDataset/PetImages/Dog"))
cat_files = [f for f in cat_files if is_image_file(f,["666.jpg"])]
dog_files = [f for f in dog_files if is_image_file(f,["11702.jpg"])]

np.random.seed(42)  # For reproducibility
np.random.shuffle(cat_files)
np.random.shuffle(dog_files)

def create_task(config):
    cat_len = len(cat_files)
    dog_len = len(dog_files)

    cat_path = "../../../dataset/DogVsCatDataset/PetImages/Cat"
    dog_path = "../../../dataset/DogVsCatDataset/PetImages/Dog"

    cat_save_path = "../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat"
    dog_save_path = "../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog"
    return [
        (config, cat_path, cat_files[0:cat_len//4], cat_save_path,0),
        (config, cat_path, cat_files[cat_len//4:cat_len//2], cat_save_path,1),
        (config, cat_path, cat_files[cat_len//2:3*cat_len//4], cat_save_path,2),
        (config, cat_path, cat_files[3*cat_len//4::], cat_save_path,3),
    
        (config, dog_path, dog_files[0:dog_len//4], dog_save_path,0),
        (config, dog_path, dog_files[dog_len//4:dog_len//2], dog_save_path,1),
        (config, dog_path, dog_files[dog_len//2:3*dog_len//4], dog_save_path,2),
        (config, dog_path, dog_files[3*dog_len//4::], dog_save_path,3),
    ]

# %%
config0 = {
    "output_shape":(128,128),
    "canny_ratios":[(0.3, 0.7), (1.2, 1.8)], 
    "scharr_combos":[(1, 0), (2.0, 0)], 
    "lbp_configs":[(16, 2), (24, 4)], 
    "gabor_configs":[0, np.pi/2]
}
task0 = create_task(config0)

# %%
with ProcessPoolExecutor(max_workers=8) as executor:
    for _ in executor.map(preprocess_wrapper, task0):...
# Out:
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_0.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_0.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_0.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_0.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_0.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_0.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_0.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_0.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_0.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_0.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_0.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_0.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_0.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_0.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_0.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_0.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_1.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_1.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_1.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_1.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_1.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_1.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_1.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_1.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_1.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_1.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_1.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_1.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_1.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_1.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_1.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_1.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_2.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_2.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_2.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_2.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_2.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_2.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_2.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_2.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_2.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_2.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_2.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_2.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_2.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_2.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_2.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_2.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_3.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_3.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_3.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_3.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_3.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_3.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_3.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_3.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_3.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_3.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_3.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_3.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_3.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_3.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_3.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_3.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_4.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_4.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_4.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_4.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_4.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_4.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_4.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_4.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_4.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_4.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_4.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_4.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_4.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_4.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_4.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_4.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_5.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_5.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_5.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_5.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_5.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_5.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_5.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_5.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_5.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_5.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_5.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_5.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_5.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_5.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_5.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_5.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_6.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_6.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_6.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_6.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_6.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_6.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_6.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_6.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_6.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_6.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_6.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_6.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_6.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_6.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_6.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_6.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_7.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_7.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_7.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_7.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_7.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_7.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_7.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_7.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_7.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_7.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_7.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_7.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_7.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_7.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_7.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_7.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_8.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_8.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_8.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_8.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_8.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_8.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_8.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_8.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_8.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_8.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_8.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_8.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_8.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_8.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_8.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_8.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_9.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_9.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_9.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_9.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_9.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_9.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_9.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_9.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_9.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_9.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_9.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_9.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_9.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_9.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_9.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_9.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_10.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_10.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_10.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_10.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_10.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_10.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_10.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_10.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_10.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_10.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_10.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_10.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_10.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_10.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_10.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_10.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_11.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_11.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_11.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_11.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_11.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_11.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_11.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_11.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_11.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_11.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_11.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_11.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_11.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_11.npy
# /home/saptak/.local/lib/python3.13/site-packages/PIL/TiffImagePlugin.py:935: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_11.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_11.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_12.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_12.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_12.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_12.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_12.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_12.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_12.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_12.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_12.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_12.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_12.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_12.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_12.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_12.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_12.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_12.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_13.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_13.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_13.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_13.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_13.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_13.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_13.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_13.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_13.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_13.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_13.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_13.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_13.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_13.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_13.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_13.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_14.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_14.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_14.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_14.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_14.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_14.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_14.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_14.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_14.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_14.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_14.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_14.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_14.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_14.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_14.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_14.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_15.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_15.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_15.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_15.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_15.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_15.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_15.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_15.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_15.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_15.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_15.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_15.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_15.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_15.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_15.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_15.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_16.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_16.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_16.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_16.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_16.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_16.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_16.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_16.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_16.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_16.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_16.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_16.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_16.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_16.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_16.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_16.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_17.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_17.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_17.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_17.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_17.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_17.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_17.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_17.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_17.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_17.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_17.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_17.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_17.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_17.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_17.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_17.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_18.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_18.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_18.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_18.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_18.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_18.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_18.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_18.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_18.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_18.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_18.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_18.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_18.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_18.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_18.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_18.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_19.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_19.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_19.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_19.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_19.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_19.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_19.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_19.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_19.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_19.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_19.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_19.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_19.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_19.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_19.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_19.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_20.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_20.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_20.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_20.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_20.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_20.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_20.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_20.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_20.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_20.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_20.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_20.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_20.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_20.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_20.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_20.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_21.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_21.npy✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_21.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_21.npy
#
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_21.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_21.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_21.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_21.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_21.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_21.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_21.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_21.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_21.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_21.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_21.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_21.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_22.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_22.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_22.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_22.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_22.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_22.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_22.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_22.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_22.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_22.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_22.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_22.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_22.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_22.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_22.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_22.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_23.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_23.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_23.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_23.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_23.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_23.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_23.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_23.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_23.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_23.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_23.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_23.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_23.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_23.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_23.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_23.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_24.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_24.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_24.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_24.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_24.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_24.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_24.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_24.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_24.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_24.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_24.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_24.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_24.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_24.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_24.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_24.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_25.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_25.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_25.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_25.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_25.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_25.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_25.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_25.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_25.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_25.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_25.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_25.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_25.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_25.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_25.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_25.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_26.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_26.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_26.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_26.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_26.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_26.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_26.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_26.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_26.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_26.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_26.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_26.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_26.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_26.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_26.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_26.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_27.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_27.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_27.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_27.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_27.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_27.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_27.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_27.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_27.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_27.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_27.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_27.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_27.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_27.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_27.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_27.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_28.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_28.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_28.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_28.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_28.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_28.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_28.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_28.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_28.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_28.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_28.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_28.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_28.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_28.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_28.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_28.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_29.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_29.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_29.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_29.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_29.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_29.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_29.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_29.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_29.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_29.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_29.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_29.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_29.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_29.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_29.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_29.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_30.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_30.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_30.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_30.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_30.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_30.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_30.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_30.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_30.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_30.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_30.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_30.npy
# ✅ Wrote (25, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/1_31.npy and (25, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/1_31.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_30.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_30.npy
# ✅ Wrote (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_30.npy and (100, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_30.npy
# ✅ Wrote (24, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/0_31.npy and (24, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/0_31.npy
# ✅ Wrote (25, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/3_31.npy and (25, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/3_31.npy
# ✅ Wrote (24, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/0_31.npy and (24, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/0_31.npy
# ✅ Wrote (25, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/3_31.npy and (25, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/3_31.npy
# ✅ Wrote (25, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/original/2_31.npy and (25, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr/2_31.npy
# ✅ Wrote (25, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/2_31.npy and (25, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/2_31.npy
# ✅ Wrote (25, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/original/1_31.npy and (25, 10, 128, 128) to ../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr/1_31.npy

# %%
cat_save_path_lr = "../../../dataset/DogVsCatDataset/preprocessed/final_split1/cat/lr"
dog_save_path_lr = "../../../dataset/DogVsCatDataset/preprocessed/final_split1/dog/lr"

cat_files = sorted(os.listdir(cat_save_path_lr))
dog_files = sorted(os.listdir(dog_save_path_lr))

np.random.seed(42)  # For reproducibility
np.random.shuffle(cat_files)
np.random.shuffle(dog_files)

train_80_cat, test_20_cat = cat_files[:int(0.8*len(cat_files))], cat_files[int(0.8*len(cat_files)):]
train_80_dog, test_20_dog = dog_files[:int(0.8*len(dog_files))], dog_files[int(0.8*len(dog_files)):]

train_50_cat, test_50_cat = cat_files[:int(0.5*len(cat_files))], cat_files[int(0.5*len(cat_files)):]
train_50_dog, test_50_dog = dog_files[:int(0.5*len(dog_files))], dog_files[int(0.5*len(dog_files)):]

state  = {
    "train80": {
        "cat": train_80_cat,
        "dog": train_80_dog,
    },
    "test20": {
        "cat": test_20_cat,
        "dog": test_20_dog,
    },

    "train50": {
        "cat": train_50_cat,
        "dog": train_50_dog,
    },
    "test50": {
        "cat": test_50_cat,
        "dog": test_50_dog,
    }
}

import json

# If you want to save only filenames (already in state), just dump it
with open("../../../dataset/DogVsCatDataset/preprocessed/final_split1/dataset_splits.json", "w") as f:
    json.dump(state, f, indent=4)
