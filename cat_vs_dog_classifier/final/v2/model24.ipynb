# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.init as init
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchinfo import summary
import seaborn as sns
import matplotlib.pyplot as plt
from ptflops import get_model_complexity_info
import os
from utils import *
from custom_layer import *
from base_model import *
import json

# %%
torch.set_num_threads(6)
# torch.set_num_interop_threads(1)
torch.backends.mkldnn.enabled = True

# %%
state = json.load(open('../../../dataset/DogVsCatDataset/preprocessed/final_split1/dataset_splits.json', 'r'))

criterion = torch.nn.CrossEntropyLoss()
train_dataset = SplitLoader("../../../dataset/DogVsCatDataset/preprocessed/final_split1/",state["train80"], batch_size=40)
test_dataset = SplitLoader("../../../dataset/DogVsCatDataset/preprocessed/final_split1/",state["test20"], batch_size=40)

# %%
model24_0 = Model3(
    norm=nn.BatchNorm2d(10),
    pool=lambda x : nn.MaxPool2d(2),
    post_conv=post_conv0,
)
he_initialization(model24_0)
describe(model24_0)
# Out:
# MACs: 24.14 MMac, Params: 3.4 k
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Model3                                   [1, 2]                    --
# ├─BatchNorm2d: 1-1                       [1, 10, 128, 128]         20
# ├─Sequential: 1-2                        [1, 10, 64, 64]           --
# │    └─Conv2d: 2-1                       [1, 20, 128, 128]         1,000
# │    └─Sequential: 2-2                   [1, 20, 128, 128]         --
# │    │    └─BatchNorm2d: 3-1             [1, 20, 128, 128]         40
# │    │    └─PReLU: 3-2                   [1, 20, 128, 128]         1
# │    └─MaxPool2d: 2-3                    [1, 20, 64, 64]           --
# │    └─Conv2d: 2-4                       [1, 10, 64, 64]           990
# │    └─Sequential: 2-5                   [1, 10, 64, 64]           --
# │    │    └─BatchNorm2d: 3-3             [1, 10, 64, 64]           20
# │    │    └─PReLU: 3-4                   [1, 10, 64, 64]           1
# ├─Sequential: 1-3                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-6                       [1, 2, 64, 64]            38
# │    └─Sequential: 2-7                   [1, 2, 64, 64]            --
# │    │    └─BatchNorm2d: 3-5             [1, 2, 64, 64]            4
# │    │    └─PReLU: 3-6                   [1, 2, 64, 64]            1
# │    └─MaxPool2d: 2-8                    [1, 2, 32, 32]            --
# │    └─Conv2d: 2-9                       [1, 1, 32, 32]            19
# │    └─Sequential: 2-10                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-7             [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-8                   [1, 1, 32, 32]            1
# │    └─MaxPool2d: 2-11                   [1, 1, 16, 16]            --
# ├─Sequential: 1-4                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-12                      [1, 2, 64, 64]            38
# │    └─Sequential: 2-13                  [1, 2, 64, 64]            --
# │    │    └─BatchNorm2d: 3-9             [1, 2, 64, 64]            4
# │    │    └─PReLU: 3-10                  [1, 2, 64, 64]            1
# │    └─MaxPool2d: 2-14                   [1, 2, 32, 32]            --
# │    └─Conv2d: 2-15                      [1, 1, 32, 32]            19
# │    └─Sequential: 2-16                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-11            [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-12                  [1, 1, 32, 32]            1
# │    └─MaxPool2d: 2-17                   [1, 1, 16, 16]            --
# ├─Sequential: 1-5                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-18                      [1, 2, 64, 64]            38
# │    └─Sequential: 2-19                  [1, 2, 64, 64]            --
# │    │    └─BatchNorm2d: 3-13            [1, 2, 64, 64]            4
# │    │    └─PReLU: 3-14                  [1, 2, 64, 64]            1
# │    └─MaxPool2d: 2-20                   [1, 2, 32, 32]            --
# │    └─Conv2d: 2-21                      [1, 1, 32, 32]            19
# │    └─Sequential: 2-22                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-15            [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-16                  [1, 1, 32, 32]            1
# │    └─MaxPool2d: 2-23                   [1, 1, 16, 16]            --
# ├─Sequential: 1-6                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-24                      [1, 2, 64, 64]            38
# │    └─Sequential: 2-25                  [1, 2, 64, 64]            --
# │    │    └─BatchNorm2d: 3-17            [1, 2, 64, 64]            4
# │    │    └─PReLU: 3-18                  [1, 2, 64, 64]            1
# │    └─MaxPool2d: 2-26                   [1, 2, 32, 32]            --
# │    └─Conv2d: 2-27                      [1, 1, 32, 32]            19
# │    └─Sequential: 2-28                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-19            [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-20                  [1, 1, 32, 32]            1
# │    └─MaxPool2d: 2-29                   [1, 1, 16, 16]            --
# ├─Sequential: 1-7                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-30                      [1, 2, 64, 64]            38
# │    └─Sequential: 2-31                  [1, 2, 64, 64]            --
# │    │    └─BatchNorm2d: 3-21            [1, 2, 64, 64]            4
# │    │    └─PReLU: 3-22                  [1, 2, 64, 64]            1
# │    └─MaxPool2d: 2-32                   [1, 2, 32, 32]            --
# │    └─Conv2d: 2-33                      [1, 1, 32, 32]            19
# │    └─Sequential: 2-34                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-23            [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-24                  [1, 1, 32, 32]            1
# │    └─MaxPool2d: 2-35                   [1, 1, 16, 16]            --
# ├─Sequential: 1-8                        [1, 5, 2, 2]              --
# │    └─Conv2d: 2-36                      [1, 5, 16, 16]            230
# │    └─Sequential: 2-37                  [1, 5, 16, 16]            --
# │    │    └─BatchNorm2d: 3-25            [1, 5, 16, 16]            10
# │    │    └─PReLU: 3-26                  [1, 5, 16, 16]            1
# │    └─MaxPool2d: 2-38                   [1, 5, 8, 8]              --
# │    └─Conv2d: 2-39                      [1, 5, 8, 8]              230
# │    └─Sequential: 2-40                  [1, 5, 8, 8]              --
# │    │    └─BatchNorm2d: 3-27            [1, 5, 8, 8]              10
# │    │    └─PReLU: 3-28                  [1, 5, 8, 8]              1
# │    └─MaxPool2d: 2-41                   [1, 5, 4, 4]              --
# │    └─Conv2d: 2-42                      [1, 5, 4, 4]              230
# │    └─Sequential: 2-43                  [1, 5, 4, 4]              --
# │    │    └─BatchNorm2d: 3-29            [1, 5, 4, 4]              10
# │    │    └─PReLU: 3-30                  [1, 5, 4, 4]              1
# │    └─MaxPool2d: 2-44                   [1, 5, 2, 2]              --
# ├─Sequential: 1-9                        [1, 2]                    --
# │    └─Flatten: 2-45                     [1, 20]                   --
# │    └─Linear: 2-46                      [1, 10]                   210
# │    └─PReLU: 2-47                       [1, 10]                   1
# │    └─Linear: 2-48                      [1, 5]                    55
# │    └─PReLU: 2-49                       [1, 5]                    1
# │    └─Linear: 2-50                      [1, 2]                    12
# ==========================================================================================
# Total params: 3,399
# Trainable params: 3,399
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 21.39
# ==========================================================================================
# Input size (MB): 0.66
# Forward/backward pass size (MB): 11.30
# Params size (MB): 0.01
# Estimated Total Size (MB): 11.97
# ==========================================================================================

# %%
train(model24_0,"model_weights/model24_0.pt",criterion,train_dataset,test_dataset)
# Out:
# Loading checkpoint from model_weights/model24_0.pt
# Starting
# Epoch 1/10: Train loss = 0.5805, Train accuracy = 0.6949, Test loss = 0.5810, Test accuracy = 0.6875
# Epoch 2/10: Train loss = 0.5281, Train accuracy = 0.7358, Test loss = 0.5334, Test accuracy = 0.7295
# Epoch 3/10: Train loss = 0.5060, Train accuracy = 0.7552, Test loss = 0.5146, Test accuracy = 0.7412
# Epoch 4/10: Train loss = 0.4865, Train accuracy = 0.7650, Test loss = 0.5051, Test accuracy = 0.7555
# Epoch 5/10: Train loss = 0.4378, Train accuracy = 0.7937, Test loss = 0.4569, Test accuracy = 0.7824
# Epoch 6/10: Train loss = 0.4270, Train accuracy = 0.8038, Test loss = 0.4422, Test accuracy = 0.7896
# Epoch 7/10: Train loss = 0.4268, Train accuracy = 0.8020, Test loss = 0.4453, Test accuracy = 0.7890
# Epoch 8/10: Train loss = 0.3885, Train accuracy = 0.8257, Test loss = 0.4137, Test accuracy = 0.8063
# Epoch 9/10: Train loss = 0.3869, Train accuracy = 0.8265, Test loss = 0.4128, Test accuracy = 0.8069
# Epoch 10/10: Train loss = 0.3824, Train accuracy = 0.8299, Test loss = 0.4108, Test accuracy = 0.8078
# Training complete.
