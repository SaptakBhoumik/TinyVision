# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.init as init
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchinfo import summary
import seaborn as sns
import matplotlib.pyplot as plt
from ptflops import get_model_complexity_info
import os
from utils import *
from custom_layer import *
from base_model import *
import json

# %%
torch.set_num_threads(6)
# torch.set_num_interop_threads(1)
torch.backends.mkldnn.enabled = True

# %%
state = json.load(open('../../../dataset/DogVsCatDataset/preprocessed/final_split1/dataset_splits.json', 'r'))

criterion = torch.nn.CrossEntropyLoss()
train_dataset = SplitLoader("../../../dataset/DogVsCatDataset/preprocessed/final_split1/",state["train80"], batch_size=40)
test_dataset = SplitLoader("../../../dataset/DogVsCatDataset/preprocessed/final_split1/",state["test20"], batch_size=40)

# %%
model26_0 = Model3(
    norm=nn.BatchNorm2d(10),
    pool=lambda x : HybridPoolingV0(x,pool1 = nn.AvgPool2d, pool2 = None),
    post_conv=post_conv0,
)
he_initialization(model26_0)
describe(model26_0)
# Out:
# MACs: 24.32 MMac, Params: 3.5 k
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Model3                                   [1, 2]                    --
# ├─BatchNorm2d: 1-1                       [1, 10, 128, 128]         20
# ├─Sequential: 1-2                        [1, 10, 64, 64]           --
# │    └─Conv2d: 2-1                       [1, 20, 128, 128]         1,000
# │    └─Sequential: 2-2                   [1, 20, 128, 128]         --
# │    │    └─BatchNorm2d: 3-1             [1, 20, 128, 128]         40
# │    │    └─PReLU: 3-2                   [1, 20, 128, 128]         1
# │    └─HybridPoolingV0: 2-3              [1, 20, 64, 64]           --
# │    │    └─AvgPool2d: 3-3               [1, 20, 64, 64]           --
# │    │    └─Sequential: 3-4              [1, 20, 64, 64]           40
# │    └─Conv2d: 2-4                       [1, 10, 64, 64]           990
# │    └─Sequential: 2-5                   [1, 10, 64, 64]           --
# │    │    └─BatchNorm2d: 3-5             [1, 10, 64, 64]           20
# │    │    └─PReLU: 3-6                   [1, 10, 64, 64]           1
# ├─Sequential: 1-3                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-6                       [1, 2, 64, 64]            38
# │    └─Sequential: 2-7                   [1, 2, 64, 64]            --
# │    │    └─BatchNorm2d: 3-7             [1, 2, 64, 64]            4
# │    │    └─PReLU: 3-8                   [1, 2, 64, 64]            1
# │    └─HybridPoolingV0: 2-8              [1, 2, 32, 32]            --
# │    │    └─AvgPool2d: 3-9               [1, 2, 32, 32]            --
# │    │    └─Sequential: 3-10             [1, 2, 32, 32]            4
# │    └─Conv2d: 2-9                       [1, 1, 32, 32]            19
# │    └─Sequential: 2-10                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-11            [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-12                  [1, 1, 32, 32]            1
# │    └─HybridPoolingV0: 2-11             [1, 1, 16, 16]            --
# │    │    └─AvgPool2d: 3-13              [1, 1, 16, 16]            --
# │    │    └─Sequential: 3-14             [1, 1, 16, 16]            2
# ├─Sequential: 1-4                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-12                      [1, 2, 64, 64]            38
# │    └─Sequential: 2-13                  [1, 2, 64, 64]            --
# │    │    └─BatchNorm2d: 3-15            [1, 2, 64, 64]            4
# │    │    └─PReLU: 3-16                  [1, 2, 64, 64]            1
# │    └─HybridPoolingV0: 2-14             [1, 2, 32, 32]            --
# │    │    └─AvgPool2d: 3-17              [1, 2, 32, 32]            --
# │    │    └─Sequential: 3-18             [1, 2, 32, 32]            4
# │    └─Conv2d: 2-15                      [1, 1, 32, 32]            19
# │    └─Sequential: 2-16                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-19            [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-20                  [1, 1, 32, 32]            1
# │    └─HybridPoolingV0: 2-17             [1, 1, 16, 16]            --
# │    │    └─AvgPool2d: 3-21              [1, 1, 16, 16]            --
# │    │    └─Sequential: 3-22             [1, 1, 16, 16]            2
# ├─Sequential: 1-5                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-18                      [1, 2, 64, 64]            38
# │    └─Sequential: 2-19                  [1, 2, 64, 64]            --
# │    │    └─BatchNorm2d: 3-23            [1, 2, 64, 64]            4
# │    │    └─PReLU: 3-24                  [1, 2, 64, 64]            1
# │    └─HybridPoolingV0: 2-20             [1, 2, 32, 32]            --
# │    │    └─AvgPool2d: 3-25              [1, 2, 32, 32]            --
# │    │    └─Sequential: 3-26             [1, 2, 32, 32]            4
# │    └─Conv2d: 2-21                      [1, 1, 32, 32]            19
# │    └─Sequential: 2-22                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-27            [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-28                  [1, 1, 32, 32]            1
# │    └─HybridPoolingV0: 2-23             [1, 1, 16, 16]            --
# │    │    └─AvgPool2d: 3-29              [1, 1, 16, 16]            --
# │    │    └─Sequential: 3-30             [1, 1, 16, 16]            2
# ├─Sequential: 1-6                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-24                      [1, 2, 64, 64]            38
# │    └─Sequential: 2-25                  [1, 2, 64, 64]            --
# │    │    └─BatchNorm2d: 3-31            [1, 2, 64, 64]            4
# │    │    └─PReLU: 3-32                  [1, 2, 64, 64]            1
# │    └─HybridPoolingV0: 2-26             [1, 2, 32, 32]            --
# │    │    └─AvgPool2d: 3-33              [1, 2, 32, 32]            --
# │    │    └─Sequential: 3-34             [1, 2, 32, 32]            4
# │    └─Conv2d: 2-27                      [1, 1, 32, 32]            19
# │    └─Sequential: 2-28                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-35            [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-36                  [1, 1, 32, 32]            1
# │    └─HybridPoolingV0: 2-29             [1, 1, 16, 16]            --
# │    │    └─AvgPool2d: 3-37              [1, 1, 16, 16]            --
# │    │    └─Sequential: 3-38             [1, 1, 16, 16]            2
# ├─Sequential: 1-7                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-30                      [1, 2, 64, 64]            38
# │    └─Sequential: 2-31                  [1, 2, 64, 64]            --
# │    │    └─BatchNorm2d: 3-39            [1, 2, 64, 64]            4
# │    │    └─PReLU: 3-40                  [1, 2, 64, 64]            1
# │    └─HybridPoolingV0: 2-32             [1, 2, 32, 32]            --
# │    │    └─AvgPool2d: 3-41              [1, 2, 32, 32]            --
# │    │    └─Sequential: 3-42             [1, 2, 32, 32]            4
# │    └─Conv2d: 2-33                      [1, 1, 32, 32]            19
# │    └─Sequential: 2-34                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-43            [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-44                  [1, 1, 32, 32]            1
# │    └─HybridPoolingV0: 2-35             [1, 1, 16, 16]            --
# │    │    └─AvgPool2d: 3-45              [1, 1, 16, 16]            --
# │    │    └─Sequential: 3-46             [1, 1, 16, 16]            2
# ├─Sequential: 1-8                        [1, 5, 2, 2]              --
# │    └─Conv2d: 2-36                      [1, 5, 16, 16]            230
# │    └─Sequential: 2-37                  [1, 5, 16, 16]            --
# │    │    └─BatchNorm2d: 3-47            [1, 5, 16, 16]            10
# │    │    └─PReLU: 3-48                  [1, 5, 16, 16]            1
# │    └─HybridPoolingV0: 2-38             [1, 5, 8, 8]              --
# │    │    └─AvgPool2d: 3-49              [1, 5, 8, 8]              --
# │    │    └─Sequential: 3-50             [1, 5, 8, 8]              10
# │    └─Conv2d: 2-39                      [1, 5, 8, 8]              230
# │    └─Sequential: 2-40                  [1, 5, 8, 8]              --
# │    │    └─BatchNorm2d: 3-51            [1, 5, 8, 8]              10
# │    │    └─PReLU: 3-52                  [1, 5, 8, 8]              1
# │    └─HybridPoolingV0: 2-41             [1, 5, 4, 4]              --
# │    │    └─AvgPool2d: 3-53              [1, 5, 4, 4]              --
# │    │    └─Sequential: 3-54             [1, 5, 4, 4]              10
# │    └─Conv2d: 2-42                      [1, 5, 4, 4]              230
# │    └─Sequential: 2-43                  [1, 5, 4, 4]              --
# │    │    └─BatchNorm2d: 3-55            [1, 5, 4, 4]              10
# │    │    └─PReLU: 3-56                  [1, 5, 4, 4]              1
# │    └─HybridPoolingV0: 2-44             [1, 5, 2, 2]              --
# │    │    └─AvgPool2d: 3-57              [1, 5, 2, 2]              --
# │    │    └─Sequential: 3-58             [1, 5, 2, 2]              10
# ├─Sequential: 1-9                        [1, 2]                    --
# │    └─Flatten: 2-45                     [1, 20]                   --
# │    └─Linear: 2-46                      [1, 10]                   210
# │    └─PReLU: 2-47                       [1, 10]                   1
# │    └─Linear: 2-48                      [1, 5]                    55
# │    └─PReLU: 2-49                       [1, 5]                    1
# │    └─Linear: 2-50                      [1, 2]                    12
# ==========================================================================================
# Total params: 3,499
# Trainable params: 3,499
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 21.39
# ==========================================================================================
# Input size (MB): 0.66
# Forward/backward pass size (MB): 12.06
# Params size (MB): 0.01
# Estimated Total Size (MB): 12.72
# ==========================================================================================

# %%
train(model26_0,"model_weights/model26_0.pt",criterion,train_dataset,test_dataset)
# Out:
# Loading checkpoint from model_weights/model26_0.pt
# Starting
# Epoch 1/10: Train loss = 0.5157, Train accuracy = 0.7491, Test loss = 0.5237, Test accuracy = 0.7400
# Epoch 2/10: Train loss = 0.4744, Train accuracy = 0.7749, Test loss = 0.4840, Test accuracy = 0.7715
# Epoch 3/10: Train loss = 0.4466, Train accuracy = 0.7923, Test loss = 0.4565, Test accuracy = 0.7841
# Epoch 4/10: Train loss = 0.4745, Train accuracy = 0.7699, Test loss = 0.4901, Test accuracy = 0.7630
# Epoch 5/10: Train loss = 0.4018, Train accuracy = 0.8185, Test loss = 0.4197, Test accuracy = 0.8073
# Epoch 6/10: Train loss = 0.3952, Train accuracy = 0.8239, Test loss = 0.4072, Test accuracy = 0.8154
# Epoch 7/10: Train loss = 0.3782, Train accuracy = 0.8307, Test loss = 0.3975, Test accuracy = 0.8196
# Epoch 8/10: Train loss = 0.3713, Train accuracy = 0.8349, Test loss = 0.3923, Test accuracy = 0.8253
# Epoch 9/10: Train loss = 0.3715, Train accuracy = 0.8358, Test loss = 0.3924, Test accuracy = 0.8224
# Epoch 10/10: Train loss = 0.3693, Train accuracy = 0.8377, Test loss = 0.3931, Test accuracy = 0.8219
# Training complete.
