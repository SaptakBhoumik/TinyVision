# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.init as init
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchinfo import summary
import seaborn as sns
import matplotlib.pyplot as plt
from ptflops import get_model_complexity_info
import os
from utils import *
from custom_layer import *
from base_model import *
import json

# %%
torch.set_num_threads(6)
# torch.set_num_interop_threads(1)
torch.backends.mkldnn.enabled = True

# %%
state = json.load(open('../../../dataset/DogVsCatDataset/preprocessed/final_split1/dataset_splits.json', 'r'))

criterion = torch.nn.CrossEntropyLoss()
train_dataset = SplitLoader("../../../dataset/DogVsCatDataset/preprocessed/final_split1/",state["train80"], batch_size=40)
test_dataset = SplitLoader("../../../dataset/DogVsCatDataset/preprocessed/final_split1/",state["test20"], batch_size=40)

# %%
model7_0 = Model0(
    norm=nn.BatchNorm2d(10),
    pool=lambda x : nn.AvgPool2d(2),
    post_conv=post_conv0
)
he_initialization(model7_0)
describe(model7_0)
# Out:
# MACs: 29.25 MMac, Params: 8.05 k
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Model0                                   [1, 2]                    --
# ├─BatchNorm2d: 1-1                       [1, 10, 128, 128]         20
# ├─Sequential: 1-2                        [1, 10, 64, 64]           --
# │    └─Conv2d: 2-1                       [1, 20, 128, 128]         1,000
# │    └─Sequential: 2-2                   [1, 20, 128, 128]         --
# │    │    └─BatchNorm2d: 3-1             [1, 20, 128, 128]         40
# │    │    └─PReLU: 3-2                   [1, 20, 128, 128]         1
# │    └─AvgPool2d: 2-3                    [1, 20, 64, 64]           --
# │    └─Conv2d: 2-4                       [1, 10, 64, 64]           990
# │    └─Sequential: 2-5                   [1, 10, 64, 64]           --
# │    │    └─BatchNorm2d: 3-3             [1, 10, 64, 64]           20
# │    │    └─PReLU: 3-4                   [1, 10, 64, 64]           1
# ├─Sequential: 1-3                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-6                       [1, 8, 64, 64]            152
# │    └─Sequential: 2-7                   [1, 8, 64, 64]            --
# │    │    └─BatchNorm2d: 3-5             [1, 8, 64, 64]            16
# │    │    └─PReLU: 3-6                   [1, 8, 64, 64]            1
# │    └─AvgPool2d: 2-8                    [1, 8, 32, 32]            --
# │    └─Conv2d: 2-9                       [1, 4, 32, 32]            292
# │    └─Sequential: 2-10                  [1, 4, 32, 32]            --
# │    │    └─BatchNorm2d: 3-7             [1, 4, 32, 32]            8
# │    │    └─PReLU: 3-8                   [1, 4, 32, 32]            1
# │    └─Conv2d: 2-11                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-12                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-9             [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-10                  [1, 2, 32, 32]            1
# │    └─AvgPool2d: 2-13                   [1, 2, 16, 16]            --
# │    └─Conv2d: 2-14                      [1, 1, 16, 16]            19
# │    └─Sequential: 2-15                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-11            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-12                  [1, 1, 16, 16]            1
# ├─Sequential: 1-4                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-16                      [1, 8, 64, 64]            152
# │    └─Sequential: 2-17                  [1, 8, 64, 64]            --
# │    │    └─BatchNorm2d: 3-13            [1, 8, 64, 64]            16
# │    │    └─PReLU: 3-14                  [1, 8, 64, 64]            1
# │    └─AvgPool2d: 2-18                   [1, 8, 32, 32]            --
# │    └─Conv2d: 2-19                      [1, 4, 32, 32]            292
# │    └─Sequential: 2-20                  [1, 4, 32, 32]            --
# │    │    └─BatchNorm2d: 3-15            [1, 4, 32, 32]            8
# │    │    └─PReLU: 3-16                  [1, 4, 32, 32]            1
# │    └─Conv2d: 2-21                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-22                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-17            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-18                  [1, 2, 32, 32]            1
# │    └─AvgPool2d: 2-23                   [1, 2, 16, 16]            --
# │    └─Conv2d: 2-24                      [1, 1, 16, 16]            19
# │    └─Sequential: 2-25                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-19            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-20                  [1, 1, 16, 16]            1
# ├─Sequential: 1-5                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-26                      [1, 8, 64, 64]            152
# │    └─Sequential: 2-27                  [1, 8, 64, 64]            --
# │    │    └─BatchNorm2d: 3-21            [1, 8, 64, 64]            16
# │    │    └─PReLU: 3-22                  [1, 8, 64, 64]            1
# │    └─AvgPool2d: 2-28                   [1, 8, 32, 32]            --
# │    └─Conv2d: 2-29                      [1, 4, 32, 32]            292
# │    └─Sequential: 2-30                  [1, 4, 32, 32]            --
# │    │    └─BatchNorm2d: 3-23            [1, 4, 32, 32]            8
# │    │    └─PReLU: 3-24                  [1, 4, 32, 32]            1
# │    └─Conv2d: 2-31                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-32                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-25            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-26                  [1, 2, 32, 32]            1
# │    └─AvgPool2d: 2-33                   [1, 2, 16, 16]            --
# │    └─Conv2d: 2-34                      [1, 1, 16, 16]            19
# │    └─Sequential: 2-35                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-27            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-28                  [1, 1, 16, 16]            1
# ├─Sequential: 1-6                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-36                      [1, 8, 64, 64]            152
# │    └─Sequential: 2-37                  [1, 8, 64, 64]            --
# │    │    └─BatchNorm2d: 3-29            [1, 8, 64, 64]            16
# │    │    └─PReLU: 3-30                  [1, 8, 64, 64]            1
# │    └─AvgPool2d: 2-38                   [1, 8, 32, 32]            --
# │    └─Conv2d: 2-39                      [1, 4, 32, 32]            292
# │    └─Sequential: 2-40                  [1, 4, 32, 32]            --
# │    │    └─BatchNorm2d: 3-31            [1, 4, 32, 32]            8
# │    │    └─PReLU: 3-32                  [1, 4, 32, 32]            1
# │    └─Conv2d: 2-41                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-42                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-33            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-34                  [1, 2, 32, 32]            1
# │    └─AvgPool2d: 2-43                   [1, 2, 16, 16]            --
# │    └─Conv2d: 2-44                      [1, 1, 16, 16]            19
# │    └─Sequential: 2-45                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-35            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-36                  [1, 1, 16, 16]            1
# ├─Sequential: 1-7                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-46                      [1, 8, 64, 64]            152
# │    └─Sequential: 2-47                  [1, 8, 64, 64]            --
# │    │    └─BatchNorm2d: 3-37            [1, 8, 64, 64]            16
# │    │    └─PReLU: 3-38                  [1, 8, 64, 64]            1
# │    └─AvgPool2d: 2-48                   [1, 8, 32, 32]            --
# │    └─Conv2d: 2-49                      [1, 4, 32, 32]            292
# │    └─Sequential: 2-50                  [1, 4, 32, 32]            --
# │    │    └─BatchNorm2d: 3-39            [1, 4, 32, 32]            8
# │    │    └─PReLU: 3-40                  [1, 4, 32, 32]            1
# │    └─Conv2d: 2-51                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-52                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-41            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-42                  [1, 2, 32, 32]            1
# │    └─AvgPool2d: 2-53                   [1, 2, 16, 16]            --
# │    └─Conv2d: 2-54                      [1, 1, 16, 16]            19
# │    └─Sequential: 2-55                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-43            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-44                  [1, 1, 16, 16]            1
# ├─Sequential: 1-8                        [1, 5, 2, 2]              --
# │    └─Conv2d: 2-56                      [1, 10, 16, 16]           460
# │    └─Sequential: 2-57                  [1, 10, 16, 16]           --
# │    │    └─BatchNorm2d: 3-45            [1, 10, 16, 16]           20
# │    │    └─PReLU: 3-46                  [1, 10, 16, 16]           1
# │    └─AvgPool2d: 2-58                   [1, 10, 8, 8]             --
# │    └─Conv2d: 2-59                      [1, 5, 8, 8]              455
# │    └─Sequential: 2-60                  [1, 5, 8, 8]              --
# │    │    └─BatchNorm2d: 3-47            [1, 5, 8, 8]              10
# │    │    └─PReLU: 3-48                  [1, 5, 8, 8]              1
# │    └─Conv2d: 2-61                      [1, 10, 8, 8]             460
# │    └─Sequential: 2-62                  [1, 10, 8, 8]             --
# │    │    └─BatchNorm2d: 3-49            [1, 10, 8, 8]             20
# │    │    └─PReLU: 3-50                  [1, 10, 8, 8]             1
# │    └─AvgPool2d: 2-63                   [1, 10, 4, 4]             --
# │    └─Conv2d: 2-64                      [1, 5, 4, 4]              455
# │    └─Sequential: 2-65                  [1, 5, 4, 4]              --
# │    │    └─BatchNorm2d: 3-51            [1, 5, 4, 4]              10
# │    │    └─PReLU: 3-52                  [1, 5, 4, 4]              1
# │    └─Conv2d: 2-66                      [1, 10, 4, 4]             460
# │    └─Sequential: 2-67                  [1, 10, 4, 4]             --
# │    │    └─BatchNorm2d: 3-53            [1, 10, 4, 4]             20
# │    │    └─PReLU: 3-54                  [1, 10, 4, 4]             1
# │    └─AvgPool2d: 2-68                   [1, 10, 2, 2]             --
# │    └─Conv2d: 2-69                      [1, 5, 2, 2]              455
# │    └─Sequential: 2-70                  [1, 5, 2, 2]              --
# │    │    └─BatchNorm2d: 3-55            [1, 5, 2, 2]              10
# │    │    └─PReLU: 3-56                  [1, 5, 2, 2]              1
# ├─Sequential: 1-9                        [1, 2]                    --
# │    └─Flatten: 2-71                     [1, 20]                   --
# │    └─Linear: 2-72                      [1, 10]                   210
# │    └─PReLU: 2-73                       [1, 10]                   1
# │    └─Linear: 2-74                      [1, 5]                    55
# │    └─PReLU: 2-75                       [1, 5]                    1
# │    └─Linear: 2-76                      [1, 2]                    12
# ==========================================================================================
# Total params: 8,047
# Trainable params: 8,047
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 25.64
# ==========================================================================================
# Input size (MB): 0.66
# Forward/backward pass size (MB): 14.95
# Params size (MB): 0.03
# Estimated Total Size (MB): 15.64
# ==========================================================================================

# %%
train(model7_0,"model_weights/model7_0.pt",criterion,train_dataset,test_dataset)
# Out:
# Loading checkpoint from model_weights/model7_0.pt
# Starting
# Epoch 1/10: Train loss = 0.4722, Train accuracy = 0.7751, Test loss = 0.4759, Test accuracy = 0.7733
# Epoch 2/10: Train loss = 0.4353, Train accuracy = 0.8006, Test loss = 0.4409, Test accuracy = 0.7910
# Epoch 3/10: Train loss = 0.4143, Train accuracy = 0.8132, Test loss = 0.4172, Test accuracy = 0.7996
# Epoch 4/10: Train loss = 0.4369, Train accuracy = 0.7998, Test loss = 0.4523, Test accuracy = 0.7892
# Epoch 5/10: Train loss = 0.3940, Train accuracy = 0.8228, Test loss = 0.4136, Test accuracy = 0.8074
# Epoch 6/10: Train loss = 0.3697, Train accuracy = 0.8336, Test loss = 0.3889, Test accuracy = 0.8213
# Epoch 7/10: Train loss = 0.3593, Train accuracy = 0.8410, Test loss = 0.3747, Test accuracy = 0.8304
# Epoch 8/10: Train loss = 0.3366, Train accuracy = 0.8530, Test loss = 0.3631, Test accuracy = 0.8382
# Epoch 9/10: Train loss = 0.3319, Train accuracy = 0.8552, Test loss = 0.3602, Test accuracy = 0.8403
# Epoch 10/10: Train loss = 0.3293, Train accuracy = 0.8572, Test loss = 0.3593, Test accuracy = 0.8388
# Training complete.
