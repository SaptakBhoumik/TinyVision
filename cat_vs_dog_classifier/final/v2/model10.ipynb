# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.init as init
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchinfo import summary
import seaborn as sns
import matplotlib.pyplot as plt
from ptflops import get_model_complexity_info
import os
from utils import *
from custom_layer import *
from base_model import *
import json

# %%
torch.set_num_threads(6)
# torch.set_num_interop_threads(1)
torch.backends.mkldnn.enabled = True

# %%
state = json.load(open('../../../dataset/DogVsCatDataset/preprocessed/final_split1/dataset_splits.json', 'r'))

criterion = torch.nn.CrossEntropyLoss()
train_dataset = SplitLoader("../../../dataset/DogVsCatDataset/preprocessed/final_split1/",state["train80"], batch_size=40)
test_dataset = SplitLoader("../../../dataset/DogVsCatDataset/preprocessed/final_split1/",state["test20"], batch_size=40)

# %%
model10_0 = Model0(
    norm=nn.BatchNorm2d(10),
    pool=lambda x : nn.MaxPool2d(2),
    post_conv=post_conv0,
    ratio = 1
)
he_initialization(model10_0)
describe(model10_0)
# Out:
# MACs: 25.62 MMac, Params: 4.79 k
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Model0                                   [1, 2]                    --
# ├─BatchNorm2d: 1-1                       [1, 10, 128, 128]         20
# ├─Sequential: 1-2                        [1, 10, 64, 64]           --
# │    └─Conv2d: 2-1                       [1, 20, 128, 128]         1,000
# │    └─Sequential: 2-2                   [1, 20, 128, 128]         --
# │    │    └─BatchNorm2d: 3-1             [1, 20, 128, 128]         40
# │    │    └─PReLU: 3-2                   [1, 20, 128, 128]         1
# │    └─MaxPool2d: 2-3                    [1, 20, 64, 64]           --
# │    └─Conv2d: 2-4                       [1, 10, 64, 64]           990
# │    └─Sequential: 2-5                   [1, 10, 64, 64]           --
# │    │    └─BatchNorm2d: 3-3             [1, 10, 64, 64]           20
# │    │    └─PReLU: 3-4                   [1, 10, 64, 64]           1
# ├─Sequential: 1-3                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-6                       [1, 4, 64, 64]            76
# │    └─Sequential: 2-7                   [1, 4, 64, 64]            --
# │    │    └─BatchNorm2d: 3-5             [1, 4, 64, 64]            8
# │    │    └─PReLU: 3-6                   [1, 4, 64, 64]            1
# │    └─MaxPool2d: 2-8                    [1, 4, 32, 32]            --
# │    └─Conv2d: 2-9                       [1, 2, 32, 32]            74
# │    └─Sequential: 2-10                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-7             [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-8                   [1, 2, 32, 32]            1
# │    └─Conv2d: 2-11                      [1, 1, 32, 32]            19
# │    └─Sequential: 2-12                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-9             [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-10                  [1, 1, 32, 32]            1
# │    └─MaxPool2d: 2-13                   [1, 1, 16, 16]            --
# │    └─Conv2d: 2-14                      [1, 1, 16, 16]            10
# │    └─Sequential: 2-15                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-11            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-12                  [1, 1, 16, 16]            1
# ├─Sequential: 1-4                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-16                      [1, 4, 64, 64]            76
# │    └─Sequential: 2-17                  [1, 4, 64, 64]            --
# │    │    └─BatchNorm2d: 3-13            [1, 4, 64, 64]            8
# │    │    └─PReLU: 3-14                  [1, 4, 64, 64]            1
# │    └─MaxPool2d: 2-18                   [1, 4, 32, 32]            --
# │    └─Conv2d: 2-19                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-20                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-15            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-16                  [1, 2, 32, 32]            1
# │    └─Conv2d: 2-21                      [1, 1, 32, 32]            19
# │    └─Sequential: 2-22                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-17            [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-18                  [1, 1, 32, 32]            1
# │    └─MaxPool2d: 2-23                   [1, 1, 16, 16]            --
# │    └─Conv2d: 2-24                      [1, 1, 16, 16]            10
# │    └─Sequential: 2-25                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-19            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-20                  [1, 1, 16, 16]            1
# ├─Sequential: 1-5                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-26                      [1, 4, 64, 64]            76
# │    └─Sequential: 2-27                  [1, 4, 64, 64]            --
# │    │    └─BatchNorm2d: 3-21            [1, 4, 64, 64]            8
# │    │    └─PReLU: 3-22                  [1, 4, 64, 64]            1
# │    └─MaxPool2d: 2-28                   [1, 4, 32, 32]            --
# │    └─Conv2d: 2-29                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-30                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-23            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-24                  [1, 2, 32, 32]            1
# │    └─Conv2d: 2-31                      [1, 1, 32, 32]            19
# │    └─Sequential: 2-32                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-25            [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-26                  [1, 1, 32, 32]            1
# │    └─MaxPool2d: 2-33                   [1, 1, 16, 16]            --
# │    └─Conv2d: 2-34                      [1, 1, 16, 16]            10
# │    └─Sequential: 2-35                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-27            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-28                  [1, 1, 16, 16]            1
# ├─Sequential: 1-6                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-36                      [1, 4, 64, 64]            76
# │    └─Sequential: 2-37                  [1, 4, 64, 64]            --
# │    │    └─BatchNorm2d: 3-29            [1, 4, 64, 64]            8
# │    │    └─PReLU: 3-30                  [1, 4, 64, 64]            1
# │    └─MaxPool2d: 2-38                   [1, 4, 32, 32]            --
# │    └─Conv2d: 2-39                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-40                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-31            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-32                  [1, 2, 32, 32]            1
# │    └─Conv2d: 2-41                      [1, 1, 32, 32]            19
# │    └─Sequential: 2-42                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-33            [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-34                  [1, 1, 32, 32]            1
# │    └─MaxPool2d: 2-43                   [1, 1, 16, 16]            --
# │    └─Conv2d: 2-44                      [1, 1, 16, 16]            10
# │    └─Sequential: 2-45                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-35            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-36                  [1, 1, 16, 16]            1
# ├─Sequential: 1-7                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-46                      [1, 4, 64, 64]            76
# │    └─Sequential: 2-47                  [1, 4, 64, 64]            --
# │    │    └─BatchNorm2d: 3-37            [1, 4, 64, 64]            8
# │    │    └─PReLU: 3-38                  [1, 4, 64, 64]            1
# │    └─MaxPool2d: 2-48                   [1, 4, 32, 32]            --
# │    └─Conv2d: 2-49                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-50                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-39            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-40                  [1, 2, 32, 32]            1
# │    └─Conv2d: 2-51                      [1, 1, 32, 32]            19
# │    └─Sequential: 2-52                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-41            [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-42                  [1, 1, 32, 32]            1
# │    └─MaxPool2d: 2-53                   [1, 1, 16, 16]            --
# │    └─Conv2d: 2-54                      [1, 1, 16, 16]            10
# │    └─Sequential: 2-55                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-43            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-44                  [1, 1, 16, 16]            1
# ├─Sequential: 1-8                        [1, 5, 2, 2]              --
# │    └─Conv2d: 2-56                      [1, 5, 16, 16]            230
# │    └─Sequential: 2-57                  [1, 5, 16, 16]            --
# │    │    └─BatchNorm2d: 3-45            [1, 5, 16, 16]            10
# │    │    └─PReLU: 3-46                  [1, 5, 16, 16]            1
# │    └─MaxPool2d: 2-58                   [1, 5, 8, 8]              --
# │    └─Conv2d: 2-59                      [1, 5, 8, 8]              230
# │    └─Sequential: 2-60                  [1, 5, 8, 8]              --
# │    │    └─BatchNorm2d: 3-47            [1, 5, 8, 8]              10
# │    │    └─PReLU: 3-48                  [1, 5, 8, 8]              1
# │    └─Conv2d: 2-61                      [1, 5, 8, 8]              230
# │    └─Sequential: 2-62                  [1, 5, 8, 8]              --
# │    │    └─BatchNorm2d: 3-49            [1, 5, 8, 8]              10
# │    │    └─PReLU: 3-50                  [1, 5, 8, 8]              1
# │    └─MaxPool2d: 2-63                   [1, 5, 4, 4]              --
# │    └─Conv2d: 2-64                      [1, 5, 4, 4]              230
# │    └─Sequential: 2-65                  [1, 5, 4, 4]              --
# │    │    └─BatchNorm2d: 3-51            [1, 5, 4, 4]              10
# │    │    └─PReLU: 3-52                  [1, 5, 4, 4]              1
# │    └─Conv2d: 2-66                      [1, 5, 4, 4]              230
# │    └─Sequential: 2-67                  [1, 5, 4, 4]              --
# │    │    └─BatchNorm2d: 3-53            [1, 5, 4, 4]              10
# │    │    └─PReLU: 3-54                  [1, 5, 4, 4]              1
# │    └─MaxPool2d: 2-68                   [1, 5, 2, 2]              --
# │    └─Conv2d: 2-69                      [1, 5, 2, 2]              230
# │    └─Sequential: 2-70                  [1, 5, 2, 2]              --
# │    │    └─BatchNorm2d: 3-55            [1, 5, 2, 2]              10
# │    │    └─PReLU: 3-56                  [1, 5, 2, 2]              1
# ├─Sequential: 1-9                        [1, 2]                    --
# │    └─Flatten: 2-71                     [1, 20]                   --
# │    └─Linear: 2-72                      [1, 10]                   210
# │    └─PReLU: 2-73                       [1, 10]                   1
# │    └─Linear: 2-74                      [1, 5]                    55
# │    └─PReLU: 2-75                       [1, 5]                    1
# │    └─Linear: 2-76                      [1, 2]                    12
# ==========================================================================================
# Total params: 4,792
# Trainable params: 4,792
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 22.58
# ==========================================================================================
# Input size (MB): 0.66
# Forward/backward pass size (MB): 12.57
# Params size (MB): 0.02
# Estimated Total Size (MB): 13.25
# ==========================================================================================

# %%
train(model10_0,"model_weights/model10_0.pt",criterion,train_dataset,test_dataset)
# Out:
# Loading checkpoint from model_weights/model10_0.pt
# Starting
# Epoch 1/10: Train loss = 0.5887, Train accuracy = 0.6894, Test loss = 0.5927, Test accuracy = 0.6814
# Epoch 2/10: Train loss = 0.5372, Train accuracy = 0.7349, Test loss = 0.5518, Test accuracy = 0.7223
# Epoch 3/10: Train loss = 0.4980, Train accuracy = 0.7594, Test loss = 0.5169, Test accuracy = 0.7401
# Epoch 4/10: Train loss = 0.4728, Train accuracy = 0.7762, Test loss = 0.5003, Test accuracy = 0.7578
# Epoch 5/10: Train loss = 0.4442, Train accuracy = 0.7930, Test loss = 0.4668, Test accuracy = 0.7780
# Epoch 6/10: Train loss = 0.4309, Train accuracy = 0.7993, Test loss = 0.4585, Test accuracy = 0.7856
# Epoch 7/10: Train loss = 0.4272, Train accuracy = 0.8011, Test loss = 0.4529, Test accuracy = 0.7884
# Epoch 8/10: Train loss = 0.3992, Train accuracy = 0.8193, Test loss = 0.4314, Test accuracy = 0.8038
# Epoch 9/10: Train loss = 0.3878, Train accuracy = 0.8282, Test loss = 0.4263, Test accuracy = 0.8037
# Epoch 10/10: Train loss = 0.3936, Train accuracy = 0.8211, Test loss = 0.4331, Test accuracy = 0.7981
# Training complete.
