# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.init as init
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchinfo import summary
import seaborn as sns
import matplotlib.pyplot as plt
from ptflops import get_model_complexity_info
import os
from utils import *
from custom_layer import *
from base_model import *
import json

# %%
torch.set_num_threads(6)
# torch.set_num_interop_threads(1)
torch.backends.mkldnn.enabled = True

# %%
state = json.load(open('../../../dataset/DogVsCatDataset/preprocessed/final_split1/dataset_splits.json', 'r'))

criterion = torch.nn.CrossEntropyLoss()
train_dataset = SplitLoader("../../../dataset/DogVsCatDataset/preprocessed/final_split1/",state["train80"], batch_size=40)
test_dataset = SplitLoader("../../../dataset/DogVsCatDataset/preprocessed/final_split1/",state["test20"], batch_size=40)

# %%
model14_0 = Model0(
    norm=nn.BatchNorm2d(10),
    pool=lambda x : HybridPoolingV0(x,pool1 = nn.AvgPool2d, pool2 = nn.MaxPool2d),
    post_conv=post_conv0,
)
he_initialization(model14_0)
describe(model14_0)
# Out:
# MACs: 30.52 MMac, Params: 8.25 k
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Model0                                   [1, 2]                    --
# ├─BatchNorm2d: 1-1                       [1, 10, 128, 128]         20
# ├─Sequential: 1-2                        [1, 10, 64, 64]           --
# │    └─Conv2d: 2-1                       [1, 20, 128, 128]         1,000
# │    └─Sequential: 2-2                   [1, 20, 128, 128]         --
# │    │    └─BatchNorm2d: 3-1             [1, 20, 128, 128]         40
# │    │    └─PReLU: 3-2                   [1, 20, 128, 128]         1
# │    └─HybridPoolingV0: 2-3              [1, 20, 64, 64]           --
# │    │    └─AvgPool2d: 3-3               [1, 20, 64, 64]           --
# │    │    └─MaxPool2d: 3-4               [1, 20, 64, 64]           --
# │    │    └─Sequential: 3-5              [1, 20, 64, 64]           40
# │    └─Conv2d: 2-4                       [1, 10, 64, 64]           990
# │    └─Sequential: 2-5                   [1, 10, 64, 64]           --
# │    │    └─BatchNorm2d: 3-6             [1, 10, 64, 64]           20
# │    │    └─PReLU: 3-7                   [1, 10, 64, 64]           1
# ├─Sequential: 1-3                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-6                       [1, 8, 64, 64]            152
# │    └─Sequential: 2-7                   [1, 8, 64, 64]            --
# │    │    └─BatchNorm2d: 3-8             [1, 8, 64, 64]            16
# │    │    └─PReLU: 3-9                   [1, 8, 64, 64]            1
# │    └─HybridPoolingV0: 2-8              [1, 8, 32, 32]            --
# │    │    └─AvgPool2d: 3-10              [1, 8, 32, 32]            --
# │    │    └─MaxPool2d: 3-11              [1, 8, 32, 32]            --
# │    │    └─Sequential: 3-12             [1, 8, 32, 32]            16
# │    └─Conv2d: 2-9                       [1, 4, 32, 32]            292
# │    └─Sequential: 2-10                  [1, 4, 32, 32]            --
# │    │    └─BatchNorm2d: 3-13            [1, 4, 32, 32]            8
# │    │    └─PReLU: 3-14                  [1, 4, 32, 32]            1
# │    └─Conv2d: 2-11                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-12                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-15            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-16                  [1, 2, 32, 32]            1
# │    └─HybridPoolingV0: 2-13             [1, 2, 16, 16]            --
# │    │    └─AvgPool2d: 3-17              [1, 2, 16, 16]            --
# │    │    └─MaxPool2d: 3-18              [1, 2, 16, 16]            --
# │    │    └─Sequential: 3-19             [1, 2, 16, 16]            4
# │    └─Conv2d: 2-14                      [1, 1, 16, 16]            19
# │    └─Sequential: 2-15                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-20            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-21                  [1, 1, 16, 16]            1
# ├─Sequential: 1-4                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-16                      [1, 8, 64, 64]            152
# │    └─Sequential: 2-17                  [1, 8, 64, 64]            --
# │    │    └─BatchNorm2d: 3-22            [1, 8, 64, 64]            16
# │    │    └─PReLU: 3-23                  [1, 8, 64, 64]            1
# │    └─HybridPoolingV0: 2-18             [1, 8, 32, 32]            --
# │    │    └─AvgPool2d: 3-24              [1, 8, 32, 32]            --
# │    │    └─MaxPool2d: 3-25              [1, 8, 32, 32]            --
# │    │    └─Sequential: 3-26             [1, 8, 32, 32]            16
# │    └─Conv2d: 2-19                      [1, 4, 32, 32]            292
# │    └─Sequential: 2-20                  [1, 4, 32, 32]            --
# │    │    └─BatchNorm2d: 3-27            [1, 4, 32, 32]            8
# │    │    └─PReLU: 3-28                  [1, 4, 32, 32]            1
# │    └─Conv2d: 2-21                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-22                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-29            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-30                  [1, 2, 32, 32]            1
# │    └─HybridPoolingV0: 2-23             [1, 2, 16, 16]            --
# │    │    └─AvgPool2d: 3-31              [1, 2, 16, 16]            --
# │    │    └─MaxPool2d: 3-32              [1, 2, 16, 16]            --
# │    │    └─Sequential: 3-33             [1, 2, 16, 16]            4
# │    └─Conv2d: 2-24                      [1, 1, 16, 16]            19
# │    └─Sequential: 2-25                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-34            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-35                  [1, 1, 16, 16]            1
# ├─Sequential: 1-5                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-26                      [1, 8, 64, 64]            152
# │    └─Sequential: 2-27                  [1, 8, 64, 64]            --
# │    │    └─BatchNorm2d: 3-36            [1, 8, 64, 64]            16
# │    │    └─PReLU: 3-37                  [1, 8, 64, 64]            1
# │    └─HybridPoolingV0: 2-28             [1, 8, 32, 32]            --
# │    │    └─AvgPool2d: 3-38              [1, 8, 32, 32]            --
# │    │    └─MaxPool2d: 3-39              [1, 8, 32, 32]            --
# │    │    └─Sequential: 3-40             [1, 8, 32, 32]            16
# │    └─Conv2d: 2-29                      [1, 4, 32, 32]            292
# │    └─Sequential: 2-30                  [1, 4, 32, 32]            --
# │    │    └─BatchNorm2d: 3-41            [1, 4, 32, 32]            8
# │    │    └─PReLU: 3-42                  [1, 4, 32, 32]            1
# │    └─Conv2d: 2-31                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-32                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-43            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-44                  [1, 2, 32, 32]            1
# │    └─HybridPoolingV0: 2-33             [1, 2, 16, 16]            --
# │    │    └─AvgPool2d: 3-45              [1, 2, 16, 16]            --
# │    │    └─MaxPool2d: 3-46              [1, 2, 16, 16]            --
# │    │    └─Sequential: 3-47             [1, 2, 16, 16]            4
# │    └─Conv2d: 2-34                      [1, 1, 16, 16]            19
# │    └─Sequential: 2-35                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-48            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-49                  [1, 1, 16, 16]            1
# ├─Sequential: 1-6                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-36                      [1, 8, 64, 64]            152
# │    └─Sequential: 2-37                  [1, 8, 64, 64]            --
# │    │    └─BatchNorm2d: 3-50            [1, 8, 64, 64]            16
# │    │    └─PReLU: 3-51                  [1, 8, 64, 64]            1
# │    └─HybridPoolingV0: 2-38             [1, 8, 32, 32]            --
# │    │    └─AvgPool2d: 3-52              [1, 8, 32, 32]            --
# │    │    └─MaxPool2d: 3-53              [1, 8, 32, 32]            --
# │    │    └─Sequential: 3-54             [1, 8, 32, 32]            16
# │    └─Conv2d: 2-39                      [1, 4, 32, 32]            292
# │    └─Sequential: 2-40                  [1, 4, 32, 32]            --
# │    │    └─BatchNorm2d: 3-55            [1, 4, 32, 32]            8
# │    │    └─PReLU: 3-56                  [1, 4, 32, 32]            1
# │    └─Conv2d: 2-41                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-42                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-57            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-58                  [1, 2, 32, 32]            1
# │    └─HybridPoolingV0: 2-43             [1, 2, 16, 16]            --
# │    │    └─AvgPool2d: 3-59              [1, 2, 16, 16]            --
# │    │    └─MaxPool2d: 3-60              [1, 2, 16, 16]            --
# │    │    └─Sequential: 3-61             [1, 2, 16, 16]            4
# │    └─Conv2d: 2-44                      [1, 1, 16, 16]            19
# │    └─Sequential: 2-45                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-62            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-63                  [1, 1, 16, 16]            1
# ├─Sequential: 1-7                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-46                      [1, 8, 64, 64]            152
# │    └─Sequential: 2-47                  [1, 8, 64, 64]            --
# │    │    └─BatchNorm2d: 3-64            [1, 8, 64, 64]            16
# │    │    └─PReLU: 3-65                  [1, 8, 64, 64]            1
# │    └─HybridPoolingV0: 2-48             [1, 8, 32, 32]            --
# │    │    └─AvgPool2d: 3-66              [1, 8, 32, 32]            --
# │    │    └─MaxPool2d: 3-67              [1, 8, 32, 32]            --
# │    │    └─Sequential: 3-68             [1, 8, 32, 32]            16
# │    └─Conv2d: 2-49                      [1, 4, 32, 32]            292
# │    └─Sequential: 2-50                  [1, 4, 32, 32]            --
# │    │    └─BatchNorm2d: 3-69            [1, 4, 32, 32]            8
# │    │    └─PReLU: 3-70                  [1, 4, 32, 32]            1
# │    └─Conv2d: 2-51                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-52                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-71            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-72                  [1, 2, 32, 32]            1
# │    └─HybridPoolingV0: 2-53             [1, 2, 16, 16]            --
# │    │    └─AvgPool2d: 3-73              [1, 2, 16, 16]            --
# │    │    └─MaxPool2d: 3-74              [1, 2, 16, 16]            --
# │    │    └─Sequential: 3-75             [1, 2, 16, 16]            4
# │    └─Conv2d: 2-54                      [1, 1, 16, 16]            19
# │    └─Sequential: 2-55                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-76            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-77                  [1, 1, 16, 16]            1
# ├─Sequential: 1-8                        [1, 5, 2, 2]              --
# │    └─Conv2d: 2-56                      [1, 10, 16, 16]           460
# │    └─Sequential: 2-57                  [1, 10, 16, 16]           --
# │    │    └─BatchNorm2d: 3-78            [1, 10, 16, 16]           20
# │    │    └─PReLU: 3-79                  [1, 10, 16, 16]           1
# │    └─HybridPoolingV0: 2-58             [1, 10, 8, 8]             --
# │    │    └─AvgPool2d: 3-80              [1, 10, 8, 8]             --
# │    │    └─MaxPool2d: 3-81              [1, 10, 8, 8]             --
# │    │    └─Sequential: 3-82             [1, 10, 8, 8]             20
# │    └─Conv2d: 2-59                      [1, 5, 8, 8]              455
# │    └─Sequential: 2-60                  [1, 5, 8, 8]              --
# │    │    └─BatchNorm2d: 3-83            [1, 5, 8, 8]              10
# │    │    └─PReLU: 3-84                  [1, 5, 8, 8]              1
# │    └─Conv2d: 2-61                      [1, 10, 8, 8]             460
# │    └─Sequential: 2-62                  [1, 10, 8, 8]             --
# │    │    └─BatchNorm2d: 3-85            [1, 10, 8, 8]             20
# │    │    └─PReLU: 3-86                  [1, 10, 8, 8]             1
# │    └─HybridPoolingV0: 2-63             [1, 10, 4, 4]             --
# │    │    └─AvgPool2d: 3-87              [1, 10, 4, 4]             --
# │    │    └─MaxPool2d: 3-88              [1, 10, 4, 4]             --
# │    │    └─Sequential: 3-89             [1, 10, 4, 4]             20
# │    └─Conv2d: 2-64                      [1, 5, 4, 4]              455
# │    └─Sequential: 2-65                  [1, 5, 4, 4]              --
# │    │    └─BatchNorm2d: 3-90            [1, 5, 4, 4]              10
# │    │    └─PReLU: 3-91                  [1, 5, 4, 4]              1
# │    └─Conv2d: 2-66                      [1, 10, 4, 4]             460
# │    └─Sequential: 2-67                  [1, 10, 4, 4]             --
# │    │    └─BatchNorm2d: 3-92            [1, 10, 4, 4]             20
# │    │    └─PReLU: 3-93                  [1, 10, 4, 4]             1
# │    └─HybridPoolingV0: 2-68             [1, 10, 2, 2]             --
# │    │    └─AvgPool2d: 3-94              [1, 10, 2, 2]             --
# │    │    └─MaxPool2d: 3-95              [1, 10, 2, 2]             --
# │    │    └─Sequential: 3-96             [1, 10, 2, 2]             20
# │    └─Conv2d: 2-69                      [1, 5, 2, 2]              455
# │    └─Sequential: 2-70                  [1, 5, 2, 2]              --
# │    │    └─BatchNorm2d: 3-97            [1, 5, 2, 2]              10
# │    │    └─PReLU: 3-98                  [1, 5, 2, 2]              1
# ├─Sequential: 1-9                        [1, 2]                    --
# │    └─Flatten: 2-71                     [1, 20]                   --
# │    └─Linear: 2-72                      [1, 10]                   210
# │    └─PReLU: 2-73                       [1, 10]                   1
# │    └─Linear: 2-74                      [1, 5]                    55
# │    └─PReLU: 2-75                       [1, 5]                    1
# │    └─Linear: 2-76                      [1, 2]                    12
# ==========================================================================================
# Total params: 8,247
# Trainable params: 8,247
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 25.64
# ==========================================================================================
# Input size (MB): 0.66
# Forward/backward pass size (MB): 15.96
# Params size (MB): 0.03
# Estimated Total Size (MB): 16.65
# ==========================================================================================

# %%
train(model14_0,"model_weights/model14_0.pt",criterion,train_dataset,test_dataset)
# Out:
# Loading checkpoint from model_weights/model14_0.pt
# Starting
# Epoch 1/10: Train loss = 0.4912, Train accuracy = 0.7645, Test loss = 0.4909, Test accuracy = 0.7623
# Epoch 2/10: Train loss = 0.4183, Train accuracy = 0.8088, Test loss = 0.4229, Test accuracy = 0.8022
# Epoch 3/10: Train loss = 0.3846, Train accuracy = 0.8281, Test loss = 0.3954, Test accuracy = 0.8196
# Epoch 4/10: Train loss = 0.3919, Train accuracy = 0.8246, Test loss = 0.4150, Test accuracy = 0.8154
# Epoch 5/10: Train loss = 0.3444, Train accuracy = 0.8500, Test loss = 0.3777, Test accuracy = 0.8319
# Epoch 6/10: Train loss = 0.3313, Train accuracy = 0.8557, Test loss = 0.3709, Test accuracy = 0.8369
# Epoch 7/10: Train loss = 0.3606, Train accuracy = 0.8386, Test loss = 0.3987, Test accuracy = 0.8197
# Epoch 8/10: Train loss = 0.3090, Train accuracy = 0.8683, Test loss = 0.3546, Test accuracy = 0.8413
# Epoch 9/10: Train loss = 0.2972, Train accuracy = 0.8725, Test loss = 0.3511, Test accuracy = 0.8453
# Epoch 10/10: Train loss = 0.2945, Train accuracy = 0.8746, Test loss = 0.3543, Test accuracy = 0.8461
# Training complete.
