# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.init as init
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchinfo import summary
import seaborn as sns
import matplotlib.pyplot as plt
from ptflops import get_model_complexity_info
import os
from utils import *
from custom_layer import *
from base_model import *
import json

# %%
torch.set_num_threads(6)
# torch.set_num_interop_threads(1)
torch.backends.mkldnn.enabled = True

# %%
state = json.load(open('../../../dataset/DogVsCatDataset/preprocessed/final_split1/dataset_splits.json', 'r'))

criterion = torch.nn.CrossEntropyLoss()
train_dataset = SplitLoader("../../../dataset/DogVsCatDataset/preprocessed/final_split1/",state["train80"], batch_size=40)
test_dataset = SplitLoader("../../../dataset/DogVsCatDataset/preprocessed/final_split1/",state["test20"], batch_size=40)

# %%
model16_0 = Model0(
    norm=nn.BatchNorm2d(10),
    pool=lambda x : HybridPoolingV0(x,pool1 = nn.AvgPool2d, pool2 = None),
    post_conv=post_conv0,
    ratio = 1
)
he_initialization(model16_0)
describe(model16_0)
# Out:
# MACs: 25.83 MMac, Params: 4.91 k
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Model0                                   [1, 2]                    --
# ├─BatchNorm2d: 1-1                       [1, 10, 128, 128]         20
# ├─Sequential: 1-2                        [1, 10, 64, 64]           --
# │    └─Conv2d: 2-1                       [1, 20, 128, 128]         1,000
# │    └─Sequential: 2-2                   [1, 20, 128, 128]         --
# │    │    └─BatchNorm2d: 3-1             [1, 20, 128, 128]         40
# │    │    └─PReLU: 3-2                   [1, 20, 128, 128]         1
# │    └─HybridPoolingV0: 2-3              [1, 20, 64, 64]           --
# │    │    └─AvgPool2d: 3-3               [1, 20, 64, 64]           --
# │    │    └─Sequential: 3-4              [1, 20, 64, 64]           40
# │    └─Conv2d: 2-4                       [1, 10, 64, 64]           990
# │    └─Sequential: 2-5                   [1, 10, 64, 64]           --
# │    │    └─BatchNorm2d: 3-5             [1, 10, 64, 64]           20
# │    │    └─PReLU: 3-6                   [1, 10, 64, 64]           1
# ├─Sequential: 1-3                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-6                       [1, 4, 64, 64]            76
# │    └─Sequential: 2-7                   [1, 4, 64, 64]            --
# │    │    └─BatchNorm2d: 3-7             [1, 4, 64, 64]            8
# │    │    └─PReLU: 3-8                   [1, 4, 64, 64]            1
# │    └─HybridPoolingV0: 2-8              [1, 4, 32, 32]            --
# │    │    └─AvgPool2d: 3-9               [1, 4, 32, 32]            --
# │    │    └─Sequential: 3-10             [1, 4, 32, 32]            8
# │    └─Conv2d: 2-9                       [1, 2, 32, 32]            74
# │    └─Sequential: 2-10                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-11            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-12                  [1, 2, 32, 32]            1
# │    └─Conv2d: 2-11                      [1, 1, 32, 32]            19
# │    └─Sequential: 2-12                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-13            [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-14                  [1, 1, 32, 32]            1
# │    └─HybridPoolingV0: 2-13             [1, 1, 16, 16]            --
# │    │    └─AvgPool2d: 3-15              [1, 1, 16, 16]            --
# │    │    └─Sequential: 3-16             [1, 1, 16, 16]            2
# │    └─Conv2d: 2-14                      [1, 1, 16, 16]            10
# │    └─Sequential: 2-15                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-17            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-18                  [1, 1, 16, 16]            1
# ├─Sequential: 1-4                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-16                      [1, 4, 64, 64]            76
# │    └─Sequential: 2-17                  [1, 4, 64, 64]            --
# │    │    └─BatchNorm2d: 3-19            [1, 4, 64, 64]            8
# │    │    └─PReLU: 3-20                  [1, 4, 64, 64]            1
# │    └─HybridPoolingV0: 2-18             [1, 4, 32, 32]            --
# │    │    └─AvgPool2d: 3-21              [1, 4, 32, 32]            --
# │    │    └─Sequential: 3-22             [1, 4, 32, 32]            8
# │    └─Conv2d: 2-19                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-20                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-23            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-24                  [1, 2, 32, 32]            1
# │    └─Conv2d: 2-21                      [1, 1, 32, 32]            19
# │    └─Sequential: 2-22                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-25            [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-26                  [1, 1, 32, 32]            1
# │    └─HybridPoolingV0: 2-23             [1, 1, 16, 16]            --
# │    │    └─AvgPool2d: 3-27              [1, 1, 16, 16]            --
# │    │    └─Sequential: 3-28             [1, 1, 16, 16]            2
# │    └─Conv2d: 2-24                      [1, 1, 16, 16]            10
# │    └─Sequential: 2-25                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-29            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-30                  [1, 1, 16, 16]            1
# ├─Sequential: 1-5                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-26                      [1, 4, 64, 64]            76
# │    └─Sequential: 2-27                  [1, 4, 64, 64]            --
# │    │    └─BatchNorm2d: 3-31            [1, 4, 64, 64]            8
# │    │    └─PReLU: 3-32                  [1, 4, 64, 64]            1
# │    └─HybridPoolingV0: 2-28             [1, 4, 32, 32]            --
# │    │    └─AvgPool2d: 3-33              [1, 4, 32, 32]            --
# │    │    └─Sequential: 3-34             [1, 4, 32, 32]            8
# │    └─Conv2d: 2-29                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-30                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-35            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-36                  [1, 2, 32, 32]            1
# │    └─Conv2d: 2-31                      [1, 1, 32, 32]            19
# │    └─Sequential: 2-32                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-37            [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-38                  [1, 1, 32, 32]            1
# │    └─HybridPoolingV0: 2-33             [1, 1, 16, 16]            --
# │    │    └─AvgPool2d: 3-39              [1, 1, 16, 16]            --
# │    │    └─Sequential: 3-40             [1, 1, 16, 16]            2
# │    └─Conv2d: 2-34                      [1, 1, 16, 16]            10
# │    └─Sequential: 2-35                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-41            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-42                  [1, 1, 16, 16]            1
# ├─Sequential: 1-6                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-36                      [1, 4, 64, 64]            76
# │    └─Sequential: 2-37                  [1, 4, 64, 64]            --
# │    │    └─BatchNorm2d: 3-43            [1, 4, 64, 64]            8
# │    │    └─PReLU: 3-44                  [1, 4, 64, 64]            1
# │    └─HybridPoolingV0: 2-38             [1, 4, 32, 32]            --
# │    │    └─AvgPool2d: 3-45              [1, 4, 32, 32]            --
# │    │    └─Sequential: 3-46             [1, 4, 32, 32]            8
# │    └─Conv2d: 2-39                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-40                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-47            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-48                  [1, 2, 32, 32]            1
# │    └─Conv2d: 2-41                      [1, 1, 32, 32]            19
# │    └─Sequential: 2-42                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-49            [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-50                  [1, 1, 32, 32]            1
# │    └─HybridPoolingV0: 2-43             [1, 1, 16, 16]            --
# │    │    └─AvgPool2d: 3-51              [1, 1, 16, 16]            --
# │    │    └─Sequential: 3-52             [1, 1, 16, 16]            2
# │    └─Conv2d: 2-44                      [1, 1, 16, 16]            10
# │    └─Sequential: 2-45                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-53            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-54                  [1, 1, 16, 16]            1
# ├─Sequential: 1-7                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-46                      [1, 4, 64, 64]            76
# │    └─Sequential: 2-47                  [1, 4, 64, 64]            --
# │    │    └─BatchNorm2d: 3-55            [1, 4, 64, 64]            8
# │    │    └─PReLU: 3-56                  [1, 4, 64, 64]            1
# │    └─HybridPoolingV0: 2-48             [1, 4, 32, 32]            --
# │    │    └─AvgPool2d: 3-57              [1, 4, 32, 32]            --
# │    │    └─Sequential: 3-58             [1, 4, 32, 32]            8
# │    └─Conv2d: 2-49                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-50                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-59            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-60                  [1, 2, 32, 32]            1
# │    └─Conv2d: 2-51                      [1, 1, 32, 32]            19
# │    └─Sequential: 2-52                  [1, 1, 32, 32]            --
# │    │    └─BatchNorm2d: 3-61            [1, 1, 32, 32]            2
# │    │    └─PReLU: 3-62                  [1, 1, 32, 32]            1
# │    └─HybridPoolingV0: 2-53             [1, 1, 16, 16]            --
# │    │    └─AvgPool2d: 3-63              [1, 1, 16, 16]            --
# │    │    └─Sequential: 3-64             [1, 1, 16, 16]            2
# │    └─Conv2d: 2-54                      [1, 1, 16, 16]            10
# │    └─Sequential: 2-55                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-65            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-66                  [1, 1, 16, 16]            1
# ├─Sequential: 1-8                        [1, 5, 2, 2]              --
# │    └─Conv2d: 2-56                      [1, 5, 16, 16]            230
# │    └─Sequential: 2-57                  [1, 5, 16, 16]            --
# │    │    └─BatchNorm2d: 3-67            [1, 5, 16, 16]            10
# │    │    └─PReLU: 3-68                  [1, 5, 16, 16]            1
# │    └─HybridPoolingV0: 2-58             [1, 5, 8, 8]              --
# │    │    └─AvgPool2d: 3-69              [1, 5, 8, 8]              --
# │    │    └─Sequential: 3-70             [1, 5, 8, 8]              10
# │    └─Conv2d: 2-59                      [1, 5, 8, 8]              230
# │    └─Sequential: 2-60                  [1, 5, 8, 8]              --
# │    │    └─BatchNorm2d: 3-71            [1, 5, 8, 8]              10
# │    │    └─PReLU: 3-72                  [1, 5, 8, 8]              1
# │    └─Conv2d: 2-61                      [1, 5, 8, 8]              230
# │    └─Sequential: 2-62                  [1, 5, 8, 8]              --
# │    │    └─BatchNorm2d: 3-73            [1, 5, 8, 8]              10
# │    │    └─PReLU: 3-74                  [1, 5, 8, 8]              1
# │    └─HybridPoolingV0: 2-63             [1, 5, 4, 4]              --
# │    │    └─AvgPool2d: 3-75              [1, 5, 4, 4]              --
# │    │    └─Sequential: 3-76             [1, 5, 4, 4]              10
# │    └─Conv2d: 2-64                      [1, 5, 4, 4]              230
# │    └─Sequential: 2-65                  [1, 5, 4, 4]              --
# │    │    └─BatchNorm2d: 3-77            [1, 5, 4, 4]              10
# │    │    └─PReLU: 3-78                  [1, 5, 4, 4]              1
# │    └─Conv2d: 2-66                      [1, 5, 4, 4]              230
# │    └─Sequential: 2-67                  [1, 5, 4, 4]              --
# │    │    └─BatchNorm2d: 3-79            [1, 5, 4, 4]              10
# │    │    └─PReLU: 3-80                  [1, 5, 4, 4]              1
# │    └─HybridPoolingV0: 2-68             [1, 5, 2, 2]              --
# │    │    └─AvgPool2d: 3-81              [1, 5, 2, 2]              --
# │    │    └─Sequential: 3-82             [1, 5, 2, 2]              10
# │    └─Conv2d: 2-69                      [1, 5, 2, 2]              230
# │    └─Sequential: 2-70                  [1, 5, 2, 2]              --
# │    │    └─BatchNorm2d: 3-83            [1, 5, 2, 2]              10
# │    │    └─PReLU: 3-84                  [1, 5, 2, 2]              1
# ├─Sequential: 1-9                        [1, 2]                    --
# │    └─Flatten: 2-71                     [1, 20]                   --
# │    └─Linear: 2-72                      [1, 10]                   210
# │    └─PReLU: 2-73                       [1, 10]                   1
# │    └─Linear: 2-74                      [1, 5]                    55
# │    └─PReLU: 2-75                       [1, 5]                    1
# │    └─Linear: 2-76                      [1, 2]                    12
# ==========================================================================================
# Total params: 4,912
# Trainable params: 4,912
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 22.58
# ==========================================================================================
# Input size (MB): 0.66
# Forward/backward pass size (MB): 13.41
# Params size (MB): 0.02
# Estimated Total Size (MB): 14.08
# ==========================================================================================

# %%
train(model16_0,"model_weights/model16_0.pt",criterion,train_dataset,test_dataset)
# Out:
# Loading checkpoint from model_weights/model16_0.pt
# Starting
# Epoch 1/10: Train loss = 0.5324, Train accuracy = 0.7351, Test loss = 0.5431, Test accuracy = 0.7274
# Epoch 2/10: Train loss = 0.4875, Train accuracy = 0.7675, Test loss = 0.5028, Test accuracy = 0.7532
# Epoch 3/10: Train loss = 0.4360, Train accuracy = 0.7983, Test loss = 0.4526, Test accuracy = 0.7864
# Epoch 4/10: Train loss = 0.4531, Train accuracy = 0.7899, Test loss = 0.4676, Test accuracy = 0.7783
# Epoch 5/10: Train loss = 0.4116, Train accuracy = 0.8134, Test loss = 0.4313, Test accuracy = 0.8030
# Epoch 6/10: Train loss = 0.3847, Train accuracy = 0.8266, Test loss = 0.4080, Test accuracy = 0.8153
# Epoch 7/10: Train loss = 0.4219, Train accuracy = 0.8051, Test loss = 0.4405, Test accuracy = 0.7946
# Epoch 8/10: Train loss = 0.3588, Train accuracy = 0.8407, Test loss = 0.3812, Test accuracy = 0.8281
# Epoch 9/10: Train loss = 0.3557, Train accuracy = 0.8416, Test loss = 0.3831, Test accuracy = 0.8276
# Epoch 10/10: Train loss = 0.3545, Train accuracy = 0.8419, Test loss = 0.3810, Test accuracy = 0.8291
# Training complete.
