# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.init as init
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchinfo import summary
import seaborn as sns
import matplotlib.pyplot as plt
from ptflops import get_model_complexity_info
import os
from utils import *
from custom_layer import *
from base_model import *
import json

# %%
torch.set_num_threads(6)
# torch.set_num_interop_threads(1)
torch.backends.mkldnn.enabled = True

# %%
state = json.load(open('../../../dataset/DogVsCatDataset/preprocessed/final_split1/dataset_splits.json', 'r'))

criterion = torch.nn.CrossEntropyLoss()
train_dataset = SplitLoader("../../../dataset/DogVsCatDataset/preprocessed/final_split1/",state["train80"], batch_size=40)
test_dataset = SplitLoader("../../../dataset/DogVsCatDataset/preprocessed/final_split1/",state["test20"], batch_size=40)

# %%
model2_0 = Model1(
    norm=nn.BatchNorm2d(10),
    post_conv=post_conv0,
    ratio=1
)
he_initialization(model2_0)
describe(model2_0)
# Out:
# MACs: 9.95 MMac, Params: 4.79 k
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Model1                                   [1, 2]                    --
# ├─BatchNorm2d: 1-1                       [1, 10, 128, 128]         20
# ├─Sequential: 1-2                        [1, 10, 64, 64]           --
# │    └─Conv2d: 2-1                       [1, 20, 64, 64]           1,000
# │    └─Sequential: 2-2                   [1, 20, 64, 64]           --
# │    │    └─BatchNorm2d: 3-1             [1, 20, 64, 64]           40
# │    │    └─PReLU: 3-2                   [1, 20, 64, 64]           1
# │    └─Conv2d: 2-3                       [1, 10, 64, 64]           990
# │    └─Sequential: 2-4                   [1, 10, 64, 64]           --
# │    │    └─BatchNorm2d: 3-3             [1, 10, 64, 64]           20
# │    │    └─PReLU: 3-4                   [1, 10, 64, 64]           1
# ├─Sequential: 1-3                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-5                       [1, 4, 32, 32]            76
# │    └─Sequential: 2-6                   [1, 4, 32, 32]            --
# │    │    └─BatchNorm2d: 3-5             [1, 4, 32, 32]            8
# │    │    └─PReLU: 3-6                   [1, 4, 32, 32]            1
# │    └─Conv2d: 2-7                       [1, 2, 32, 32]            74
# │    └─Sequential: 2-8                   [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-7             [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-8                   [1, 2, 32, 32]            1
# │    └─Conv2d: 2-9                       [1, 1, 16, 16]            19
# │    └─Sequential: 2-10                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-9             [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-10                  [1, 1, 16, 16]            1
# │    └─Conv2d: 2-11                      [1, 1, 16, 16]            10
# │    └─Sequential: 2-12                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-11            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-12                  [1, 1, 16, 16]            1
# ├─Sequential: 1-4                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-13                      [1, 4, 32, 32]            76
# │    └─Sequential: 2-14                  [1, 4, 32, 32]            --
# │    │    └─BatchNorm2d: 3-13            [1, 4, 32, 32]            8
# │    │    └─PReLU: 3-14                  [1, 4, 32, 32]            1
# │    └─Conv2d: 2-15                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-16                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-15            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-16                  [1, 2, 32, 32]            1
# │    └─Conv2d: 2-17                      [1, 1, 16, 16]            19
# │    └─Sequential: 2-18                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-17            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-18                  [1, 1, 16, 16]            1
# │    └─Conv2d: 2-19                      [1, 1, 16, 16]            10
# │    └─Sequential: 2-20                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-19            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-20                  [1, 1, 16, 16]            1
# ├─Sequential: 1-5                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-21                      [1, 4, 32, 32]            76
# │    └─Sequential: 2-22                  [1, 4, 32, 32]            --
# │    │    └─BatchNorm2d: 3-21            [1, 4, 32, 32]            8
# │    │    └─PReLU: 3-22                  [1, 4, 32, 32]            1
# │    └─Conv2d: 2-23                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-24                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-23            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-24                  [1, 2, 32, 32]            1
# │    └─Conv2d: 2-25                      [1, 1, 16, 16]            19
# │    └─Sequential: 2-26                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-25            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-26                  [1, 1, 16, 16]            1
# │    └─Conv2d: 2-27                      [1, 1, 16, 16]            10
# │    └─Sequential: 2-28                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-27            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-28                  [1, 1, 16, 16]            1
# ├─Sequential: 1-6                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-29                      [1, 4, 32, 32]            76
# │    └─Sequential: 2-30                  [1, 4, 32, 32]            --
# │    │    └─BatchNorm2d: 3-29            [1, 4, 32, 32]            8
# │    │    └─PReLU: 3-30                  [1, 4, 32, 32]            1
# │    └─Conv2d: 2-31                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-32                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-31            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-32                  [1, 2, 32, 32]            1
# │    └─Conv2d: 2-33                      [1, 1, 16, 16]            19
# │    └─Sequential: 2-34                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-33            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-34                  [1, 1, 16, 16]            1
# │    └─Conv2d: 2-35                      [1, 1, 16, 16]            10
# │    └─Sequential: 2-36                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-35            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-36                  [1, 1, 16, 16]            1
# ├─Sequential: 1-7                        [1, 1, 16, 16]            --
# │    └─Conv2d: 2-37                      [1, 4, 32, 32]            76
# │    └─Sequential: 2-38                  [1, 4, 32, 32]            --
# │    │    └─BatchNorm2d: 3-37            [1, 4, 32, 32]            8
# │    │    └─PReLU: 3-38                  [1, 4, 32, 32]            1
# │    └─Conv2d: 2-39                      [1, 2, 32, 32]            74
# │    └─Sequential: 2-40                  [1, 2, 32, 32]            --
# │    │    └─BatchNorm2d: 3-39            [1, 2, 32, 32]            4
# │    │    └─PReLU: 3-40                  [1, 2, 32, 32]            1
# │    └─Conv2d: 2-41                      [1, 1, 16, 16]            19
# │    └─Sequential: 2-42                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-41            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-42                  [1, 1, 16, 16]            1
# │    └─Conv2d: 2-43                      [1, 1, 16, 16]            10
# │    └─Sequential: 2-44                  [1, 1, 16, 16]            --
# │    │    └─BatchNorm2d: 3-43            [1, 1, 16, 16]            2
# │    │    └─PReLU: 3-44                  [1, 1, 16, 16]            1
# ├─Sequential: 1-8                        [1, 5, 2, 2]              --
# │    └─Conv2d: 2-45                      [1, 5, 8, 8]              230
# │    └─Sequential: 2-46                  [1, 5, 8, 8]              --
# │    │    └─BatchNorm2d: 3-45            [1, 5, 8, 8]              10
# │    │    └─PReLU: 3-46                  [1, 5, 8, 8]              1
# │    └─Conv2d: 2-47                      [1, 5, 8, 8]              230
# │    └─Sequential: 2-48                  [1, 5, 8, 8]              --
# │    │    └─BatchNorm2d: 3-47            [1, 5, 8, 8]              10
# │    │    └─PReLU: 3-48                  [1, 5, 8, 8]              1
# │    └─Conv2d: 2-49                      [1, 5, 4, 4]              230
# │    └─Sequential: 2-50                  [1, 5, 4, 4]              --
# │    │    └─BatchNorm2d: 3-49            [1, 5, 4, 4]              10
# │    │    └─PReLU: 3-50                  [1, 5, 4, 4]              1
# │    └─Conv2d: 2-51                      [1, 5, 4, 4]              230
# │    └─Sequential: 2-52                  [1, 5, 4, 4]              --
# │    │    └─BatchNorm2d: 3-51            [1, 5, 4, 4]              10
# │    │    └─PReLU: 3-52                  [1, 5, 4, 4]              1
# │    └─Conv2d: 2-53                      [1, 5, 2, 2]              230
# │    └─Sequential: 2-54                  [1, 5, 2, 2]              --
# │    │    └─BatchNorm2d: 3-53            [1, 5, 2, 2]              10
# │    │    └─PReLU: 3-54                  [1, 5, 2, 2]              1
# │    └─Conv2d: 2-55                      [1, 5, 2, 2]              230
# │    └─Sequential: 2-56                  [1, 5, 2, 2]              --
# │    │    └─BatchNorm2d: 3-55            [1, 5, 2, 2]              10
# │    │    └─PReLU: 3-56                  [1, 5, 2, 2]              1
# ├─Sequential: 1-9                        [1, 2]                    --
# │    └─Flatten: 2-57                     [1, 20]                   --
# │    └─Linear: 2-58                      [1, 10]                   210
# │    └─PReLU: 2-59                       [1, 10]                   1
# │    └─Linear: 2-60                      [1, 5]                    55
# │    └─PReLU: 2-61                       [1, 5]                    1
# │    └─Linear: 2-62                      [1, 2]                    12
# ==========================================================================================
# Total params: 4,792
# Trainable params: 4,792
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 9.00
# ==========================================================================================
# Input size (MB): 0.66
# Forward/backward pass size (MB): 5.08
# Params size (MB): 0.02
# Estimated Total Size (MB): 5.75
# ==========================================================================================

# %%
train(model2_0,"model_weights/model2_0.pt",criterion,train_dataset,test_dataset)
# Out:
# Loading checkpoint from model_weights/model2_0.pt
# Starting
# Epoch 1/10: Train loss = 0.5761, Train accuracy = 0.6977, Test loss = 0.5790, Test accuracy = 0.6913
# Epoch 2/10: Train loss = 0.5115, Train accuracy = 0.7537, Test loss = 0.5107, Test accuracy = 0.7547
# Epoch 3/10: Train loss = 0.4872, Train accuracy = 0.7655, Test loss = 0.4883, Test accuracy = 0.7613
# Epoch 4/10: Train loss = 0.4506, Train accuracy = 0.7931, Test loss = 0.4609, Test accuracy = 0.7811
# Epoch 5/10: Train loss = 0.4280, Train accuracy = 0.8032, Test loss = 0.4366, Test accuracy = 0.7926
# Epoch 6/10: Train loss = 0.4208, Train accuracy = 0.8085, Test loss = 0.4380, Test accuracy = 0.7978
# Epoch 7/10: Train loss = 0.3963, Train accuracy = 0.8195, Test loss = 0.4136, Test accuracy = 0.8104
# Epoch 8/10: Train loss = 0.3803, Train accuracy = 0.8304, Test loss = 0.4025, Test accuracy = 0.8121
# Epoch 9/10: Train loss = 0.3775, Train accuracy = 0.8304, Test loss = 0.4039, Test accuracy = 0.8123
# Epoch 10/10: Train loss = 0.3755, Train accuracy = 0.8342, Test loss = 0.4020, Test accuracy = 0.8137
# Training complete.
