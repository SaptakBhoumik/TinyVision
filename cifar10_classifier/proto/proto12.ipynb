# %%
from proto12 import *
from ptflops import get_model_complexity_info

# %%
modelA = ParentModule(pentary_modelA)

# %%
macs, params = get_model_complexity_info(modelA, (3,32,32), as_strings=True, print_per_layer_stat=False, verbose=False)
print(f"MACs: {macs}, Params: {params}")
# Out:
# MACs: 4.1 MMac, Params: 56.08 k

# %%
test(modelA,lr=0.01, epochs=50, batch_size=64)
# Out:
# Total parameters: 56078, Handled in optim_groups: 56078
#
# =============== Training Model ===============
#
# Epoch 001 | Loss=3.2268 | Acc=0.2526 | LR=0.01000
# Epoch 002 | Loss=1.6866 | Acc=0.3680 | LR=0.01000
# Epoch 003 | Loss=1.5410 | Acc=0.4313 | LR=0.01000
# Epoch 004 | Loss=1.4006 | Acc=0.4935 | LR=0.01000
# Epoch 005 | Loss=1.2708 | Acc=0.5419 | LR=0.01000
# Epoch 006 | Loss=1.1487 | Acc=0.5903 | LR=0.01000
# Epoch 007 | Loss=1.0616 | Acc=0.6246 | LR=0.01000
# Epoch 008 | Loss=0.9751 | Acc=0.6576 | LR=0.01000
# Epoch 009 | Loss=0.9190 | Acc=0.6790 | LR=0.01000
# Epoch 010 | Loss=0.8762 | Acc=0.6943 | LR=0.01000
# Epoch 011 | Loss=0.8391 | Acc=0.7062 | LR=0.01000
# Epoch 012 | Loss=0.8149 | Acc=0.7203 | LR=0.01000
# Epoch 013 | Loss=0.7870 | Acc=0.7287 | LR=0.01000
# Epoch 014 | Loss=0.7674 | Acc=0.7341 | LR=0.01000
# Epoch 015 | Loss=0.7513 | Acc=0.7405 | LR=0.01000
# Epoch 016 | Loss=0.7303 | Acc=0.7493 | LR=0.01000
# Epoch 017 | Loss=0.7220 | Acc=0.7505 | LR=0.01000
# ...

# %%
test(modelA,lr=0.001, epochs=10, batch_size=64)
# Out:
# Total parameters: 56078, Handled in optim_groups: 56078
#
# =============== Training Model ===============
#
# Epoch 001 | Loss=0.4936 | Acc=0.8286 | LR=0.00100
# Epoch 002 | Loss=0.4871 | Acc=0.8293 | LR=0.00100
# Epoch 003 | Loss=0.4776 | Acc=0.8336 | LR=0.00100
# Epoch 004 | Loss=0.4734 | Acc=0.8364 | LR=0.00100
# Epoch 005 | Loss=0.4734 | Acc=0.8361 | LR=0.00100
# Epoch 006 | Loss=0.4712 | Acc=0.8359 | LR=0.00100
# Epoch 007 | Loss=0.4717 | Acc=0.8360 | LR=0.00100
# Epoch 008 | Loss=0.4668 | Acc=0.8370 | LR=0.00100
# Epoch 009 | Loss=0.4664 | Acc=0.8383 | LR=0.00100
# Epoch 010 | Loss=0.4615 | Acc=0.8412 | LR=0.00100
#
# Test Loss=0.5279 | Test Acc=0.8190

# %%
test(modelA,lr=0.001, epochs=10, batch_size=64)
# Out:
# Total parameters: 56078, Handled in optim_groups: 56078
#
# =============== Training Model ===============
#
# Epoch 001 | Loss=0.4527 | Acc=0.8435 | LR=0.00100
# Epoch 002 | Loss=0.4529 | Acc=0.8428 | LR=0.00100
# Epoch 003 | Loss=0.4588 | Acc=0.8406 | LR=0.00100
# Epoch 004 | Loss=0.4555 | Acc=0.8409 | LR=0.00100
# Epoch 005 | Loss=0.4494 | Acc=0.8425 | LR=0.00100
# Epoch 006 | Loss=0.4564 | Acc=0.8411 | LR=0.00100
# Epoch 007 | Loss=0.4552 | Acc=0.8415 | LR=0.00100
# Epoch 008 | Loss=0.4500 | Acc=0.8436 | LR=0.00100
# Epoch 009 | Loss=0.4491 | Acc=0.8429 | LR=0.00100
# Epoch 010 | Loss=0.4487 | Acc=0.8452 | LR=0.00100
#
# Test Loss=0.5169 | Test Acc=0.8244

# %%
test(modelA,lr=0.0001, epochs=5, batch_size=64)
# Out:
# Total parameters: 56078, Handled in optim_groups: 56078
#
# =============== Training Model ===============
#
# Epoch 001 | Loss=0.4447 | Acc=0.8450 | LR=0.00010
# Epoch 002 | Loss=0.4495 | Acc=0.8438 | LR=0.00010
# Epoch 003 | Loss=0.4412 | Acc=0.8453 | LR=0.00010
# Epoch 004 | Loss=0.4471 | Acc=0.8443 | LR=0.00010
# Epoch 005 | Loss=0.4423 | Acc=0.8448 | LR=0.00010
#
# Test Loss=0.5087 | Test Acc=0.8288

# %%
modelB = ParentModule(regular_modelA)

# %%
macs, params = get_model_complexity_info(modelB, (3,32,32), as_strings=True, print_per_layer_stat=False, verbose=False)
print(f"MACs: {macs}, Params: {params}")
# Out:
# MACs: 5.45 MMac, Params: 56.06 k

# %%
test(modelB,lr=0.01, epochs=50, batch_size=64)
# Out:
# Total parameters: 56056, Handled in optim_groups: 56056
#
# =============== Training Model ===============
#
# Epoch 001 | Loss=1.4711 | Acc=0.4607 | LR=0.01000
# Epoch 002 | Loss=1.0617 | Acc=0.6211 | LR=0.01000
# Epoch 003 | Loss=0.9016 | Acc=0.6833 | LR=0.01000
# Epoch 004 | Loss=0.8147 | Acc=0.7173 | LR=0.01000
# Epoch 005 | Loss=0.7566 | Acc=0.7375 | LR=0.01000
# Epoch 006 | Loss=0.7117 | Acc=0.7513 | LR=0.01000
# Epoch 007 | Loss=0.6741 | Acc=0.7643 | LR=0.01000
# Epoch 008 | Loss=0.6476 | Acc=0.7759 | LR=0.01000
# Epoch 009 | Loss=0.6284 | Acc=0.7829 | LR=0.01000
# Epoch 010 | Loss=0.6063 | Acc=0.7900 | LR=0.01000
# Epoch 011 | Loss=0.5927 | Acc=0.7948 | LR=0.01000
# Epoch 012 | Loss=0.5766 | Acc=0.8010 | LR=0.01000
# Epoch 013 | Loss=0.5568 | Acc=0.8084 | LR=0.01000
# Epoch 014 | Loss=0.5472 | Acc=0.8104 | LR=0.01000
# Epoch 015 | Loss=0.5342 | Acc=0.8172 | LR=0.01000
# Epoch 016 | Loss=0.5216 | Acc=0.8197 | LR=0.01000
# Epoch 017 | Loss=0.5062 | Acc=0.8263 | LR=0.01000
# ...

# %%
test(modelB,lr=0.001, epochs=10, batch_size=64)
# Out:
# Total parameters: 56056, Handled in optim_groups: 56056
#
# =============== Training Model ===============
#
# Epoch 001 | Loss=0.2963 | Acc=0.8968 | LR=0.00100
# Epoch 002 | Loss=0.2745 | Acc=0.9049 | LR=0.00100
# Epoch 003 | Loss=0.2720 | Acc=0.9052 | LR=0.00100
# Epoch 004 | Loss=0.2651 | Acc=0.9083 | LR=0.00100
# Epoch 005 | Loss=0.2597 | Acc=0.9093 | LR=0.00100
# Epoch 006 | Loss=0.2598 | Acc=0.9092 | LR=0.00100
# Epoch 007 | Loss=0.2573 | Acc=0.9096 | LR=0.00100
# Epoch 008 | Loss=0.2547 | Acc=0.9117 | LR=0.00100
# Epoch 009 | Loss=0.2553 | Acc=0.9098 | LR=0.00100
# Epoch 010 | Loss=0.2530 | Acc=0.9121 | LR=0.00100
#
# Test Loss=0.3783 | Test Acc=0.8758

# %%
test(modelB,lr=0.001, epochs=10, batch_size=64)
# Out:
# Total parameters: 56056, Handled in optim_groups: 56056
#
# =============== Training Model ===============
#
# Epoch 001 | Loss=0.2501 | Acc=0.9126 | LR=0.00100
# Epoch 002 | Loss=0.2470 | Acc=0.9140 | LR=0.00100
# Epoch 003 | Loss=0.2466 | Acc=0.9130 | LR=0.00100
# Epoch 004 | Loss=0.2453 | Acc=0.9136 | LR=0.00100
# Epoch 005 | Loss=0.2422 | Acc=0.9148 | LR=0.00100
# Epoch 006 | Loss=0.2465 | Acc=0.9141 | LR=0.00100
# Epoch 007 | Loss=0.2410 | Acc=0.9163 | LR=0.00100
# Epoch 008 | Loss=0.2407 | Acc=0.9153 | LR=0.00100
# Epoch 009 | Loss=0.2421 | Acc=0.9151 | LR=0.00100
# Epoch 010 | Loss=0.2378 | Acc=0.9178 | LR=0.00100
#
# Test Loss=0.3748 | Test Acc=0.8785

# %%
test(modelB,lr=0.0001, epochs=5, batch_size=64)
# Out:
# Total parameters: 56056, Handled in optim_groups: 56056
#
# =============== Training Model ===============
#
# Epoch 001 | Loss=0.2325 | Acc=0.9177 | LR=0.00010
# Epoch 002 | Loss=0.2358 | Acc=0.9163 | LR=0.00010
# Epoch 003 | Loss=0.2352 | Acc=0.9178 | LR=0.00010
# Epoch 004 | Loss=0.2319 | Acc=0.9178 | LR=0.00010
# Epoch 005 | Loss=0.2317 | Acc=0.9181 | LR=0.00010
#
# Test Loss=0.3750 | Test Acc=0.8813
